# %%
import pandas as pd

# %%
df = pd.read_csv('../data/se-weather-cleaned-lean.csv')

# %%
df.loc[df['DATE_FILTER'] == '01-01']
# Out:
# Empty DataFrame
# Columns: [STATION, NAME, LATITUDE, LONGITUDE, ELEVATION, DATE, DLY-TAVG-NORMAL, DLY-TMAX-NORMAL, DLY-TMIN-NORMAL, STATE, COUNTY, ZIP, DATE_FILTER]
# Index: []

# %%
df.loc[df['ZIP'] == 27253]
# Out:
#             STATION                  NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 110166  USC00313919  HAW RIVER 1 E, NC US   36.0638    -79.383      193.9
# 110167  USC00313919  HAW RIVER 1 E, NC US   36.0638    -79.383      193.9
# 110168  USC00313919  HAW RIVER 1 E, NC US   36.0638    -79.383      193.9
# 110169  USC00313919  HAW RIVER 1 E, NC US   36.0638    -79.383      193.9
# 110170  USC00313919  HAW RIVER 1 E, NC US   36.0638    -79.383      193.9
# ...             ...                   ...       ...        ...        ...
# 110527  USC00313919  HAW RIVER 1 E, NC US   36.0638    -79.383      193.9
# 110528  USC00313919  HAW RIVER 1 E, NC US   36.0638    -79.383      193.9
# 110529  USC00313919  HAW RIVER 1 E, NC US   36.0638    -79.383      193.9
# 110530  USC00313919  HAW RIVER 1 E, NC US   36.0638    -79.383      193.9
# 110531  USC00313919  HAW RIVER 1 E, NC US   36.0638    -79.383      193.9
#
#          DATE  DLY-TAVG-NORMAL  DLY-TMAX-NORMAL  DLY-TMIN-NORMAL STATE  \
# ...
