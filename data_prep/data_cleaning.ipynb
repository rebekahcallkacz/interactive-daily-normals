# %% [markdown]
# ## Southeast USA Daily Normals
# Data Source: https://www.ncdc.noaa.gov/cdo-web/search?datasetid=NORMAL_DLY
#
# References
# * https://stackoverflow.com/questions/31511997/pandas-dataframe-replace-all-values-in-a-column-based-on-condition
# * https://jakevdp.github.io/WhirlwindTourOfPython/14-strings-and-regular-expressions.html
# * https://towardsdatascience.com/reverse-geocoding-in-python-a915acf29eb6

# %%
# Dependencies
import pandas as pd
import numpy as np
import re
import requests
import json
import time

# Google developer API key
from config import gkey

# %% [markdown]
# ### Functions

# %%
# This function takes in the station name as a string and extracts the state that the station is in
# This function returns the state two-letter code as a string
def findState(string):
    regex = re.compile(',\s([A-Z][A-Z])')
    state = regex.findall(string)
    return state[0]

# %% [markdown]
# ### Cleaning Dataset(s)

# %%
# Read in first dataset
df1 = pd.read_csv('daily-normals-SE-1.csv')
df1.head()
# Out:
#        STATION                  NAME  LATITUDE  LONGITUDE  ELEVATION   DATE  \
# 0  USC00441955  CONCORD 4 SSW, VA US   37.2819   -78.9591      248.4  01-01
# 1  USC00441955  CONCORD 4 SSW, VA US   37.2819   -78.9591      248.4  01-02
# 2  USC00441955  CONCORD 4 SSW, VA US   37.2819   -78.9591      248.4  01-03
# 3  USC00441955  CONCORD 4 SSW, VA US   37.2819   -78.9591      248.4  01-04
# 4  USC00441955  CONCORD 4 SSW, VA US   37.2819   -78.9591      248.4  01-05
#
#    DLY-TAVG-NORMAL  DLY-TAVG-STDDEV  DLY-TMAX-NORMAL  DLY-TMAX-STDDEV  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    DLY-TMIN-NORMAL  DLY-TMIN-STDDEV
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN              NaN

# %%
# Read in second dataset
df2 = pd.read_csv('daily-normals-SE-2.csv')
df2.head()
# Out:
#        STATION            NAME  LATITUDE  LONGITUDE  ELEVATION   DATE  \
# 0  USC00312827  ENFIELD, NC US   36.1686    -77.675       33.5  01-01
# 1  USC00312827  ENFIELD, NC US   36.1686    -77.675       33.5  01-02
# 2  USC00312827  ENFIELD, NC US   36.1686    -77.675       33.5  01-03
# 3  USC00312827  ENFIELD, NC US   36.1686    -77.675       33.5  01-04
# 4  USC00312827  ENFIELD, NC US   36.1686    -77.675       33.5  01-05
#
#    DLY-TAVG-NORMAL  DLY-TAVG-STDDEV  DLY-TMAX-NORMAL  DLY-TMAX-STDDEV  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    DLY-TMIN-NORMAL  DLY-TMIN-STDDEV
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN              NaN

# %%
# Read in third dataset
df3 = pd.read_csv('daily-normals-SE-3.csv')
df3.head()
# Out:
#        STATION                         NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USC00406271  MORRISTOWN RADIO WCR, TN US   36.2067   -83.3325      409.7
# 1  USC00406271  MORRISTOWN RADIO WCR, TN US   36.2067   -83.3325      409.7
# 2  USC00406271  MORRISTOWN RADIO WCR, TN US   36.2067   -83.3325      409.7
# 3  USC00406271  MORRISTOWN RADIO WCR, TN US   36.2067   -83.3325      409.7
# 4  USC00406271  MORRISTOWN RADIO WCR, TN US   36.2067   -83.3325      409.7
#
#     DATE  DLY-TAVG-NORMAL  DLY-TAVG-STDDEV  DLY-TMAX-NORMAL  DLY-TMAX-STDDEV  \
# 0  01-01             36.0             10.1             45.7             11.0
# 1  01-02             36.0             10.1             45.6             11.0
# 2  01-03             35.9             10.1             45.6             10.9
# 3  01-04             35.9             10.0             45.6             10.9
# 4  01-05             35.8             10.0             45.6             10.9
#
#    DLY-TMIN-NORMAL  DLY-TMIN-STDDEV
# 0             26.4             10.9
# 1             26.3             10.9
# 2             26.2             10.9
# 3             26.2             10.9
# 4             26.1             10.9

# %%
# Combine datasets
df = pd.concat([df1, df2, df3])
df
# Out:
#             STATION                  NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0       USC00441955  CONCORD 4 SSW, VA US   37.2819   -78.9591      248.4
# 1       USC00441955  CONCORD 4 SSW, VA US   37.2819   -78.9591      248.4
# 2       USC00441955  CONCORD 4 SSW, VA US   37.2819   -78.9591      248.4
# 3       USC00441955  CONCORD 4 SSW, VA US   37.2819   -78.9591      248.4
# 4       USC00441955  CONCORD 4 SSW, VA US   37.2819   -78.9591      248.4
# ...             ...                   ...       ...        ...        ...
# 218103  USC00017947      SULLIGENT, AL US   33.8998   -88.1326      106.7
# 218104  USC00017947      SULLIGENT, AL US   33.8998   -88.1326      106.7
# 218105  USC00017947      SULLIGENT, AL US   33.8998   -88.1326      106.7
# 218106  USC00017947      SULLIGENT, AL US   33.8998   -88.1326      106.7
# 218107  USC00017947      SULLIGENT, AL US   33.8998   -88.1326      106.7
#
#          DATE  DLY-TAVG-NORMAL  DLY-TAVG-STDDEV  DLY-TMAX-NORMAL  \
# 0       01-01              NaN              NaN              NaN
# 1       01-02              NaN              NaN              NaN
# 2       01-03              NaN              NaN              NaN
# 3       01-04              NaN              NaN              NaN
# 4       01-05              NaN              NaN              NaN
# ...       ...              ...              ...              ...
# 218103  12-27              NaN              NaN              NaN
# 218104  12-28              NaN              NaN              NaN
# 218105  12-29              NaN              NaN              NaN
# 218106  12-30              NaN              NaN              NaN
# 218107  12-31              NaN              NaN              NaN
#
#         DLY-TMAX-STDDEV  DLY-TMIN-NORMAL  DLY-TMIN-STDDEV
# 0                   NaN              NaN              NaN
# 1                   NaN              NaN              NaN
# 2                   NaN              NaN              NaN
# 3                   NaN              NaN              NaN
# 4                   NaN              NaN              NaN
# ...                 ...              ...              ...
# 218103              NaN              NaN              NaN
# 218104              NaN              NaN              NaN
# 218105              NaN              NaN              NaN
# 218106              NaN              NaN              NaN
# 218107              NaN              NaN              NaN
#
# [418300 rows x 12 columns]

# %%
# Check for missing values
df.count()
# Out:
# STATION            418300
# NAME               418300
# LATITUDE           418300
# LONGITUDE          418300
# ELEVATION          418300
# DATE               418300
# DLY-TAVG-NORMAL    342576
# DLY-TAVG-STDDEV    261690
# DLY-TMAX-NORMAL    342576
# DLY-TMAX-STDDEV    261690
# DLY-TMIN-NORMAL    342576
# DLY-TMIN-STDDEV    261690
# dtype: int64

# %%
# Drop all rows that are missing daily normals (avg, max, min)
df_clean_1 = df.dropna(subset=['DLY-TAVG-NORMAL', 'DLY-TMAX-NORMAL', 'DLY-TMIN-NORMAL'])

# %%
# Check for additional missing values
df_clean_1.count()
# Out:
# STATION            342576
# NAME               342576
# LATITUDE           342576
# LONGITUDE          342576
# ELEVATION          342576
# DATE               342576
# DLY-TAVG-NORMAL    342576
# DLY-TAVG-STDDEV    261690
# DLY-TMAX-NORMAL    342576
# DLY-TMAX-STDDEV    261690
# DLY-TMIN-NORMAL    342576
# DLY-TMIN-STDDEV    261690
# dtype: int64

# %%
df_clean_1
# Out:
#             STATION                         NAME  LATITUDE  LONGITUDE  \
# 366     USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# 367     USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# 368     USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# 369     USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# 370     USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# ...             ...                          ...       ...        ...
# 217371  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
# 217372  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
# 217373  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
# 217374  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
# 217375  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
#
#         ELEVATION   DATE  DLY-TAVG-NORMAL  DLY-TAVG-STDDEV  DLY-TMAX-NORMAL  \
# 366         289.6  01-01             29.8             10.3             38.6
# 367         289.6  01-02             29.7             10.3             38.5
# 368         289.6  01-03             29.7             10.4             38.4
# 369         289.6  01-04             29.6             10.4             38.4
# 370         289.6  01-05             29.5             10.5             38.3
# ...           ...    ...              ...              ...              ...
# 217371      243.8  12-27             38.3              NaN             47.8
# 217372      243.8  12-28             38.1              NaN             47.7
# 217373      243.8  12-29             38.0              NaN             47.6
# 217374      243.8  12-30             37.9              NaN             47.4
# 217375      243.8  12-31             37.8              NaN             47.3
#
#         DLY-TMAX-STDDEV  DLY-TMIN-NORMAL  DLY-TMIN-STDDEV
# 366                11.8             21.0             10.4
# 367                11.8             20.9             10.5
# 368                11.9             20.9             10.6
# 369                11.9             20.8             10.6
# 370                11.9             20.8             10.7
# ...                 ...              ...              ...
# 217371              NaN             28.7              NaN
# 217372              NaN             28.6              NaN
# 217373              NaN             28.5              NaN
# 217374              NaN             28.4              NaN
# 217375              NaN             28.3              NaN
#
# [342576 rows x 12 columns]

# %% [markdown]
# ### Adding State Column

# %%
# Pull state out of station name and add to state column
df_clean_2 = df_clean_1.copy()
df_clean_2['STATE'] = df_clean_2['NAME'].apply(findState)
df_clean_2
# Out:
#             STATION                         NAME  LATITUDE  LONGITUDE  \
# 366     USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# 367     USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# 368     USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# 369     USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# 370     USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# ...             ...                          ...       ...        ...
# 217371  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
# 217372  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
# 217373  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
# 217374  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
# 217375  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
#
#         ELEVATION   DATE  DLY-TAVG-NORMAL  DLY-TAVG-STDDEV  DLY-TMAX-NORMAL  \
# 366         289.6  01-01             29.8             10.3             38.6
# 367         289.6  01-02             29.7             10.3             38.5
# 368         289.6  01-03             29.7             10.4             38.4
# 369         289.6  01-04             29.6             10.4             38.4
# 370         289.6  01-05             29.5             10.5             38.3
# ...           ...    ...              ...              ...              ...
# 217371      243.8  12-27             38.3              NaN             47.8
# 217372      243.8  12-28             38.1              NaN             47.7
# 217373      243.8  12-29             38.0              NaN             47.6
# 217374      243.8  12-30             37.9              NaN             47.4
# 217375      243.8  12-31             37.8              NaN             47.3
#
#         DLY-TMAX-STDDEV  DLY-TMIN-NORMAL  DLY-TMIN-STDDEV STATE
# 366                11.8             21.0             10.4    WV
# 367                11.8             20.9             10.5    WV
# 368                11.9             20.9             10.6    WV
# 369                11.9             20.8             10.6    WV
# 370                11.9             20.8             10.7    WV
# ...                 ...              ...              ...   ...
# 217371              NaN             28.7              NaN    TN
# 217372              NaN             28.6              NaN    TN
# 217373              NaN             28.5              NaN    TN
# 217374              NaN             28.4              NaN    TN
# 217375              NaN             28.3              NaN    TN
#
# [342576 rows x 13 columns]

# %%
# Review sample to verify accurate state assignment
df_test_states = df_clean_2.sample(20)
df_test_states
# Out:
#             STATION                                     NAME  LATITUDE  \
# 182616  USC00401310                         BYRDSTOWN, TN US  36.58028
# 170322  USC00091340                         BRUNSWICK, GA US  31.16810
# 61208   USC00463215                     FRANKLIN 2 NE, WV US  38.67560
# 35442   USC00317516                     ROXBORO 7 ESE, NC US  36.34640
# 121619  USW00003804               PARKERSBURG AIRPORT, WV US  39.20000
# 118190  USC00403679  GREENEVILLE EXPERIMENTAL STATION, TN US  36.10560
# 163855  USC00404858                         KINGSPORT, TN US  36.51940
# 82758   USC00409709                       WHITE HOUSE, TN US  36.45110
# 148695  USC00013645                      HAMILTON 3 S, AL US  34.09660
# 115334  USC00467649                    ROCK CAVE 2 NE, WV US  38.85610
# 23345   USC00317615                         SALISBURY, NC US  35.68360
# 37544   USC00441593               CHARLOTTESVILLE 2 W, VA US  38.03290
# 53545   USW00053877                   ASHEVILLE 8 SSW, NC US  35.49450
# 46785   USC00154375                    KENLAKE RESORT, KY US  36.76000
# 98360   USC00405525                         LYNCHBURG, TN US  35.29830
# 141     USC00406271              MORRISTOWN RADIO WCR, TN US  36.20670
# 59434   USC00317656                      SANFORD 8 NE, NC US  35.53470
# 123015  USC00097600                              ROME, GA US  34.24130
# 55525   USC00310982                             BOONE, NC US  36.21140
# 113770  USC00386527                      ORANGEBURG 2, SC US  33.48861
#
#         LONGITUDE  ELEVATION   DATE  DLY-TAVG-NORMAL  DLY-TAVG-STDDEV  \
# 182616  -85.12556      268.2  01-05             35.2             11.5
# 170322  -81.50220        4.0  06-01             78.5              4.2
# 61208   -79.30920      579.1  03-29             46.3              9.2
# 35442   -78.88580      216.4  11-02             52.4              7.9
# 121619  -81.27000      253.3  04-23             56.5              8.7
# 118190  -82.84360      402.3  12-20             37.5             10.3
# 163855  -82.52750      391.4  09-29             64.0              6.3
# 82758   -86.64550      249.9  02-22             40.9              NaN
# 148695  -87.99130      132.6  04-27             62.4              7.2
# 115334  -80.30740      533.1  02-20             33.5             11.3
# 23345   -80.48220      213.4  10-14             60.7              6.8
# 37544   -78.52260      264.0  08-01             76.7              5.0
# 53545   -82.61420      655.6  04-21             55.0              NaN
# 46785   -88.13860      147.5  11-07             52.3              NaN
# 98360   -86.36310      246.9  10-12             59.1              NaN
# 141     -83.33250      409.7  05-21             66.6              6.2
# 59434   -79.04640       79.9  05-24             70.1              6.3
# 123015  -85.15840      208.8  02-25             48.1              8.5
# 55525   -81.64420     1024.1  09-18             60.4              5.4
# 113770  -80.87333       54.9  11-12             55.7              7.9
#
#         DLY-TMAX-NORMAL  DLY-TMAX-STDDEV  DLY-TMIN-NORMAL  DLY-TMIN-STDDEV  \
# 182616             45.5             12.8             25.0             11.7
# 170322             87.8              5.5             69.2              4.4
# 61208              59.9             11.8             32.7              9.2
# 35442              66.7              9.0             38.0              9.4
# 121619             68.7             10.5             44.2              8.9
# 118190             49.0             11.5             25.9             11.1
# 163855             76.5              6.9             51.4              7.7
# 82758              51.6              NaN             30.2              NaN
# 148695             78.0              8.0             46.8              9.0
# 115334             42.1             13.1             24.8             11.1
# 23345              73.0              7.3             48.4              8.8
# 37544              86.8              6.3             66.7              4.7
# 53545              68.7              NaN             41.4              NaN
# 46785              63.4              NaN             41.2              NaN
# 98360              73.7              NaN             44.6              NaN
# 141                78.4              6.7             54.8              7.3
# 59434              82.7              6.6             57.5              7.9
# 123015             59.6             10.5             36.6              8.9
# 55525              71.4              6.1             49.4              7.1
# 113770             68.0              8.3             43.4              9.9
#
#        STATE
# 182616    TN
# 170322    GA
# 61208     WV
# 35442     NC
# 121619    WV
# 118190    TN
# 163855    TN
# 82758     TN
# 148695    AL
# 115334    WV
# 23345     NC
# 37544     VA
# 53545     NC
# 46785     KY
# 98360     TN
# 141       TN
# 59434     NC
# 123015    GA
# 55525     NC
# 113770    SC

# %%
# Determine states included in dataset
states = df_clean_2['STATE'].unique()
states
# Out:
# array(['WV', 'VA', 'SC', 'MD', 'NC', 'TN', 'GA', 'AL', 'KY', 'IN', 'IL'],
#       dtype=object)

# %%
# Drop rows associated with states not in the Southwest
for state in ['MD', 'IN', 'IL']:
    df_clean_2.drop(df_clean_2[df_clean_2['STATE'] == state].index, inplace=True)

# Check that unwanted states were dropped
df_clean_2['STATE'].unique()
# Out:
# array(['WV', 'VA', 'SC', 'NC', 'TN', 'GA', 'AL', 'KY'], dtype=object)

# %% [markdown]
# ## Find Counties and Zip Codes for Stations

# %%
# Pull out dataframe of stations metadata
stations = df_clean_2[['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'STATE']].drop_duplicates()
stations
# Out:
#             STATION                            NAME  LATITUDE  LONGITUDE STATE
# 366     USC00461324     CACAPON STATE PARK 2, WV US   39.5064   -78.3158    WV
# 732     USC00442009                   CORBIN, VA US   38.2022   -77.3747    VA
# 1098    USC00440187      AMELIA COURTHOUSE 1, VA US   37.3451   -77.9781    VA
# 1464    USC00442245                 DANVILLE, VA US   36.5869   -79.3886    VA
# 2196    USC00466212  MORGANTOWN LOCK AND DAM, WV US   39.6203   -79.9698    WV
# ...             ...                             ...       ...        ...   ...
# 214083  USC00014798               LIVINGSTON, AL US   32.5811   -88.1897    AL
# 215180  USC00152214                  DIX DAM, KY US   37.7858   -84.7077    KY
# 215912  USC00150397            BARDSTOWN 5 E, KY US   37.8194   -85.3847    KY
# 216278  USC00152575                   ETOILE, KY US   36.8276   -85.8975    KY
# 217010  USC00402711          EAGLEVILLE 1 SW, TN US   35.7285   -86.6435    TN
#
# [932 rows x 5 columns]

# %%
# Create column that has coordinates combined in a string
stations['COORD'] = stations['LATITUDE'].map(str) + ',' + stations['LONGITUDE'].map(str)
stations
# Out:
#             STATION                            NAME  LATITUDE  LONGITUDE  \
# 366     USC00461324     CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# 732     USC00442009                   CORBIN, VA US   38.2022   -77.3747
# 1098    USC00440187      AMELIA COURTHOUSE 1, VA US   37.3451   -77.9781
# 1464    USC00442245                 DANVILLE, VA US   36.5869   -79.3886
# 2196    USC00466212  MORGANTOWN LOCK AND DAM, WV US   39.6203   -79.9698
# ...             ...                             ...       ...        ...
# 214083  USC00014798               LIVINGSTON, AL US   32.5811   -88.1897
# 215180  USC00152214                  DIX DAM, KY US   37.7858   -84.7077
# 215912  USC00150397            BARDSTOWN 5 E, KY US   37.8194   -85.3847
# 216278  USC00152575                   ETOILE, KY US   36.8276   -85.8975
# 217010  USC00402711          EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
#
#        STATE             COORD
# 366       WV  39.5064,-78.3158
# 732       VA  38.2022,-77.3747
# 1098      VA  37.3451,-77.9781
# 1464      VA  36.5869,-79.3886
# 2196      WV  39.6203,-79.9698
# ...      ...               ...
# 214083    AL  32.5811,-88.1897
# 215180    KY  37.7858,-84.7077
# 215912    KY  37.8194,-85.3847
# 216278    KY  36.8276,-85.8975
# 217010    TN  35.7285,-86.6435
#
# [932 rows x 6 columns]

# %%
# Create columns for county and zip code
stations['COUNTY'] = ''
stations['ZIP'] = ''

# %%
# Empty list for any stations missing
missing_stations = []

# Create columns for county and zip code
stations_others = stations.loc[stations['COUNTY'] == '']

# %%
# Use reverse geocoding using Google's Geocoding API to find the zipcodes and counties
for index, row in stations_others.iterrows():
    coord = row["COORD"]
    # Assemble url and make API call based on coordinates
    url = f'https://maps.googleapis.com/maps/api/geocode/json?latlng={coord}&key={gkey}'
    response = requests.get(url)
    geocoding = response.json()
    
    try:
        # Find zipcode and county within JSON response
        for dict in geocoding['results'][0]['address_components']:
            if 'administrative_area_level_2' in dict['types']:
                county = dict['long_name']
            if 'postal_code' in dict['types']:
                zipcode = dict['long_name']
        # Add zipcode and county to dataframe
        stations.loc[stations['COORD'] == coord, 'COUNTY'] = county
        stations.loc[stations['COORD'] == coord, 'ZIP'] = zipcode

        print(f'Added {coord} to DataFrame.')
        time.sleep(1)
    
    except:
        # Store any problematic coordinates
        missing_dict = {}
        missing_dict['JSON'] = geocoding
        missing_dict['COORD'] = coord
        missing_stations.append(missing_dict)
        print(f'Could not add {coord} to DataFrame')

print('Finished Processing')
# Out:
# Added 39.5064,-78.3158 to DataFrame.
# Added 38.2022,-77.3747 to DataFrame.
# Added 37.3451,-77.9781 to DataFrame.
# Added 36.5869,-79.3886 to DataFrame.
# Added 39.6203,-79.9698 to DataFrame.
# Added 39.3419,-79.6697 to DataFrame.
# Added 38.4014,-82.5266 to DataFrame.
# Added 38.1935,-81.3701 to DataFrame.
# Added 37.2889,-82.2928 to DataFrame.
# Added 38.5459,-78.0981 to DataFrame.
# Added 37.4255,-77.8915 to DataFrame.
# Added 38.3311,-79.6586 to DataFrame.
# Added 37.5894,-81.0925 to DataFrame.
# Added 36.81667,-76.03333 to DataFrame.
# Added 36.695,-76.13556 to DataFrame.
# Added 38.1873,-80.1336 to DataFrame.
# Added 38.3138,-81.7186 to DataFrame.
# Added 37.1453,-82.4911 to DataFrame.
# Added 36.6954,-78.8807 to DataFrame.
# Added 36.8628,-82.7711 to DataFrame.
# Added 37.1756,-78.2786 to DataFrame.
# Added 37.0556,-80.7842 to DataFrame.
# Added 39.0046,-80.47399999999999 to DataFrame.
# Added 38.2875,-77.4507 to DataFrame.
# Added 38.8172,-81.7119 to DataFrame.
# Added 37.6731,-82.2762 to DataFrame.
# Added 36.6002,-78.3011 to DataFrame.
# Added 36.9028,-82.0384 to DataFrame.
# Added 38.2323,-78.1202 to DataFrame.
# Added 39.4206,-79.005 to DataFrame.
# Added 38.5325,-77.8167 to DataFrame.
# Added 37.2555,-81.2263 to DataFrame.
# Added 37.9715,-81.1507 to DataFrame.
# Added 37.4313,-76.4414 to DataFrame.
# Added 36.98389,-77.00721999999999 to DataFrame.
# Added 37.708059999999996,-77.43444000000001 to DataFrame.
# Added 38.50362,-77.30503 to DataFrame.
# Added 39.013000000000005,-79.4743 to DataFrame.
# Added 38.5216,-78.4355 to DataFrame.
# Added 38.4197,-82.2986 to DataFrame.
# Added 38.9099,-81.0844 to DataFrame.
# Added 39.4658,-77.9669 to DataFrame.
# Added 36.7711,-77.7928 to DataFrame.
# Added 39.67722,-79.77194 to DataFrame.
# Added 36.9033,-76.1922 to DataFrame.
# Added 38.9803,-80.2201 to DataFrame.
# Added 38.6311,-80.0856 to DataFrame.
# Added 37.9458,-79.9542 to DataFrame.
# Added 36.8707,-76.2289 to DataFrame.
# Added 39.4467,-79.5469 to DataFrame.
# Added 36.9617,-81.087 to DataFrame.
# Added 37.64128,-80.88331 to DataFrame.
# Added 38.6611,-80.697 to DataFrame.
# Added 39.2811,-81.5572 to DataFrame.
# Added 38.3794,-81.59 to DataFrame.
# Added 38.8483,-77.0341 to DataFrame.
# Added 37.3169,-79.9741 to DataFrame.
# Added 37.505,-77.3202 to DataFrame.
# Added 38.399,-79.9949 to DataFrame.
# Added 38.2456,-78.2703 to DataFrame.
# Added 37.5247,-79.6816 to DataFrame.
# Added 37.7767,-79.4385 to DataFrame.
# Added 39.9055,-80.7549 to DataFrame.
# Added 36.937459999999994,-76.28926 to DataFrame.
# Added 38.0421,-78.0061 to DataFrame.
# Added 37.9975,-78.4656 to DataFrame.
# Added 38.4547,-78.9352 to DataFrame.
# Added 36.6687,-81.9646 to DataFrame.
# Added 38.0329,-78.5226 to DataFrame.
# Added 36.9769,-79.8961 to DataFrame.
# Added 37.7885,-80.3083 to DataFrame.
# Added 39.098,-79.4322 to DataFrame.
# Added 37.7836,-81.123 to DataFrame.
# Added 37.0156,-82.3214 to DataFrame.
# Added 39.0614,-81.4023 to DataFrame.
# Added 38.9339,-80.8317 to DataFrame.
# Added 39.47,-80.8571 to DataFrame.
# Added 37.8141,-78.2645 to DataFrame.
# Added 37.13194,-76.49306 to DataFrame.
# Added 40.176390000000005,-80.64721999999999 to DataFrame.
# Added 38.6195,-80.3821 to DataFrame.
# Added 38.9817,-81.5659 to DataFrame.
# Added 38.0111,-78.4494 to DataFrame.
# Added 37.86,-81.46300000000001 to DataFrame.
# Added 37.2822,-82.0894 to DataFrame.
# Added 37.0521,-78.6496 to DataFrame.
# Added 38.365,-82.555 to DataFrame.
# Added 38.9408,-77.4636 to DataFrame.
# Added 37.9372,-75.4708 to DataFrame.
# Added 38.3683,-78.2503 to DataFrame.
# Added 37.2907,-75.92699999999999 to DataFrame.
# Added 37.2958,-81.2077 to DataFrame.
# Added 38.13861,-78.45306 to DataFrame.
# Added 39.5436,-80.4647 to DataFrame.
# Added 38.8025,-78.5853 to DataFrame.
# Added 37.1278,-80.4033 to DataFrame.
# Added 38.6812,-77.7678 to DataFrame.
# Added 37.3261,-78.8274 to DataFrame.
# Added 38.9988,-79.13600000000001 to DataFrame.
# Added 37.5831,-75.8217 to DataFrame.
# Added 37.9881,-76.7769 to DataFrame.
# Added 36.6983,-77.5597 to DataFrame.
# Added 39.1833,-78.1167 to DataFrame.
# Added 37.5973,-81.8204 to DataFrame.
# Added 39.0461,-78.9664 to DataFrame.
# Added 38.1879,-80.8484 to DataFrame.
# Added 39.1881,-78.1514 to DataFrame.
# Added 38.6756,-79.3092 to DataFrame.
# Added 39.4667,-80.1333 to DataFrame.
# Added 37.0925,-81.3358 to DataFrame.
# Added 38.57,-79.2758 to DataFrame.
# Added 39.044000000000004,-80.4725 to DataFrame.
# Added 39.0483,-79.4406 to DataFrame.
# Added 37.0375,-77.9462 to DataFrame.
# Added 37.9892,-80.68 to DataFrame.
# Added 37.6761,-81.6213 to DataFrame.
# Added 40.1478,-80.7014 to DataFrame.
# Added 36.683,-76.7684 to DataFrame.
# Added 38.5312,-79.7714 to DataFrame.
# Added 38.5277,-81.9154 to DataFrame.
# Added 38.7506,-81.9808 to DataFrame.
# Added 38.9764,-77.4869 to DataFrame.
# Added 37.3818,-79.233 to DataFrame.
# Added 37.1122,-77.2017 to DataFrame.
# Added 39.023,-79.933 to DataFrame.
# Added 38.8072,-79.7172 to DataFrame.
# Added 37.5741,-81.5355 to DataFrame.
# Added 37.54417,-77.27583 to DataFrame.
# Added 38.4738,-80.4086 to DataFrame.
# Added 39.6466,-80.4066 to DataFrame.
# Added 36.7297,-76.6015 to DataFrame.
# Added 39.0736,-79.634 to DataFrame.
# Added 38.67889,-80.19583 to DataFrame.
# Added 37.3876,-75.9744 to DataFrame.
# Added 39.2728,-79.3684 to DataFrame.
# Added 39.1461,-80.0411 to DataFrame.
# Added 39.2906,-80.7687 to DataFrame.
# Added 38.9,-77.2663 to DataFrame.
# Added 38.6844,-82.1837 to DataFrame.
# Added 38.3064,-79.7197 to DataFrame.
# Added 37.3017,-76.7039 to DataFrame.
# Added 38.1692,-79.0844 to DataFrame.
# Added 37.75,-77.4833 to DataFrame.
# Added 37.0225,-76.3366 to DataFrame.
# Added 38.6649,-80.7672 to DataFrame.
# Added 37.9969,-79.8316 to DataFrame.
# Added 37.6363,-78.9336 to DataFrame.
# Added 37.5658,-76.8 to DataFrame.
# Added 38.8969,-78.4679 to DataFrame.
# Added 38.8009,-81.3584 to DataFrame.
# Added 36.6365,-80.2545 to DataFrame.
# Added 37.0997,-81.1161 to DataFrame.
# Added 36.5955,-76.4386 to DataFrame.
# Added 38.2869,-79.8181 to DataFrame.
# Added 38.2175,-80.0914 to DataFrame.
# Added 39.3389,-78.7728 to DataFrame.
# Added 38.7334,-77.4925 to DataFrame.
# Added 36.8894,-81.7711 to DataFrame.
# Added 37.2388,-77.3925 to DataFrame.
# Added 38.6553,-78.2272 to DataFrame.
# Added 36.6633,-80.9139 to DataFrame.
# Added 36.6542,-80.9183 to DataFrame.
# Added 40.0567,-80.7283 to DataFrame.
# Added 39.0858,-78.4441 to DataFrame.
# Added 37.7434,-77.04 to DataFrame.
# Added 38.1025,-81.8464 to DataFrame.
# Added 37.2992,-77.2775 to DataFrame.
# Added 37.81112,-79.98822 to DataFrame.
# Added 38.0802,-78.875 to DataFrame.
# Added 39.219,-81.0486 to DataFrame.
# Added 37.0679,-78.9517 to DataFrame.
# Added 37.5436,-80.5336 to DataFrame.
# Added 39.0878,-77.6928 to DataFrame.
# Added 36.6213,-78.5506 to DataFrame.
# Added 38.8853,-79.8528 to DataFrame.
# Added 36.5729,-79.3351 to DataFrame.
# Added 37.2008,-80.5864 to DataFrame.
# Added 38.9452,-78.798 to DataFrame.
# Added 36.7056,-79.865 to DataFrame.
# Added 38.1211,-81.1179 to DataFrame.
# Added 38.2062,-80.5205 to DataFrame.
# Added 37.0924,-81.7935 to DataFrame.
# Added 37.2714,-80.7131 to DataFrame.
# Added 39.64278,-79.91639 to DataFrame.
# Added 39.4019,-77.9844 to DataFrame.
# Added 37.3208,-79.2067 to DataFrame.
# Added 36.8224,-79.4104 to DataFrame.
# Added 37.2039,-80.4144 to DataFrame.
# Added 38.8561,-80.3074 to DataFrame.
# Added 38.2794,-82.1114 to DataFrame.
# Added 36.73806,-82.99667 to DataFrame.
# Added 37.3263,-78.3864 to DataFrame.
# Added 37.6664,-77.8769 to DataFrame.
# Added 36.9839,-77.0078 to DataFrame.
# Added 36.9742,-77.4041 to DataFrame.
# Added 37.8566,-80.4042 to DataFrame.
# Added 38.2201,-80.8938 to DataFrame.
# Added 36.9725,-82.5579 to DataFrame.
# Added 37.08278,-76.36028 to DataFrame.
# Added 39.2,-81.27 to DataFrame.
# Added 37.9496,-82.4046 to DataFrame.
# Added 39.2682,-80.3522 to DataFrame.
# Added 36.7775,-78.4756 to DataFrame.
# Added 38.9038,-78.1821 to DataFrame.
# Added 37.7647,-81.194 to DataFrame.
# Added 39.295559999999995,-80.22889 to DataFrame.
# Added 37.866,-81.9845 to DataFrame.
# Added 37.7091,-78.2885 to DataFrame.
# Added 37.7272,-80.6592 to DataFrame.
# Added 37.5784,-81.3272 to DataFrame.
# Added 39.3134,-80.0299 to DataFrame.
# Added 37.3616,-79.9591 to DataFrame.
# Added 38.6661,-78.3727 to DataFrame.
# Added 39.1139,-78.5811 to DataFrame.
# Added 36.2067,-83.3325 to DataFrame.
# Added 31.6953,-82.9239 to DataFrame.
# Added 36.1682,-83.4027 to DataFrame.
# Added 33.4527,-87.3572 to DataFrame.
# Added 31.1769,-83.7491 to DataFrame.
# Added 32.5575,-82.9036 to DataFrame.
# Added 32.8711,-86.1758 to DataFrame.
# Added 35.0711,-89.4117 to DataFrame.
# Added 31.1902,-84.2036 to DataFrame.
# Added 34.7582,-84.7642 to DataFrame.
# Added 35.414,-86.8086 to DataFrame.
# Added 35.0311,-85.2014 to DataFrame.
# Added 34.8879,-83.3966 to DataFrame.
# Added 34.5686,-85.6063 to DataFrame.
# Added 37.16861,-84.93916999999999 to DataFrame.
# Added 36.6736,-84.4791 to DataFrame.
# Added 33.3644,-81.9633 to DataFrame.
# Added 32.13,-81.21 to DataFrame.
# Added 36.5877,-86.5258 to DataFrame.
# Added 35.2803,-85.2414 to DataFrame.
# Added 32.2003,-83.2058 to DataFrame.
# Added 34.51,-87.7319 to DataFrame.
# Added 36.471,-86.8415 to DataFrame.
# Added 35.0564,-89.9865 to DataFrame.
# Added 32.411,-87.0144 to DataFrame.
# Added 35.8181,-83.9858 to DataFrame.
# Added 38.3636,-85.4186 to DataFrame.
# Added 37.0563,-88.7744 to DataFrame.
# Added 36.11889,-86.68916999999999 to DataFrame.
# Added 35.2191,-84.7921 to DataFrame.
# Added 34.7441,-87.5997 to DataFrame.
# Added 32.2997,-86.4075 to DataFrame.
# Added 37.3997,-87.7622 to DataFrame.
# Added 30.68833,-88.24556 to DataFrame.
# Added 36.5514,-84.7968 to DataFrame.
# Added 36.474000000000004,-81.8033 to DataFrame.
# Added 34.64389,-86.78611 to DataFrame.
# Added 36.1482,-85.2649 to DataFrame.
# Added 30.783609999999996,-83.56917 to DataFrame.
# Added 34.6159,-83.5429 to DataFrame.
# Added 35.2436,-87.3508 to DataFrame.
# Added 35.0781,-89.6653 to DataFrame.
# Added 31.8075,-85.9722 to DataFrame.
# Added 35.1524,-88.3213 to DataFrame.
# Added 32.9205,-86.6708 to DataFrame.
# Added 36.354,-82.2486 to DataFrame.
# Added 37.08722,-84.07694000000001 to DataFrame.
# Added 35.6381,-87.0864 to DataFrame.
# Added 37.8604,-83.897 to DataFrame.
# Added 37.15,-83.81667 to DataFrame.
# Added 31.25,-82.4 to DataFrame.
# Added 35.998000000000005,-84.2192 to DataFrame.
# Added 30.3875,-88.227 to DataFrame.
# Added 35.2243,-85.8414 to DataFrame.
# Added 37.1244,-87.8672 to DataFrame.
# Added 35.9509,-85.0813 to DataFrame.
# Added 31.535559999999997,-84.19444 to DataFrame.
# Added 31.70028,-83.62306 to DataFrame.
# Added 35.6082,-88.12 to DataFrame.
# Added 35.5392,-86.2284 to DataFrame.
# Added 36.060829999999996,-86.90639 to DataFrame.
# Added 34.0588,-85.2338 to DataFrame.
# Added 33.5872,-85.8556 to DataFrame.
# Added 31.5358,-82.5067 to DataFrame.
# Added 32.0142,-85.7464 to DataFrame.
# Added 31.1522,-81.3908 to DataFrame.
# Added 36.4731,-82.4044 to DataFrame.
# Added 33.56556,-86.745 to DataFrame.
# Added 33.6301,-84.4418 to DataFrame.
# Added 33.948,-83.3275 to DataFrame.
# Added 38.6869,-83.7872 to DataFrame.
# Added 33.5635,-83.0768 to DataFrame.
# Added 33.7264,-82.7059 to DataFrame.
# Added 31.860559999999996,-86.01222 to DataFrame.
# Added 35.9106,-86.5578 to DataFrame.
# Added 34.10139,-84.35056 to DataFrame.
# Added 35.8375,-86.0894 to DataFrame.
# Added 35.3041,-87.7591 to DataFrame.
# Added 34.1175,-83.3044 to DataFrame.
# Added 34.2043,-84.7925 to DataFrame.
# Added 34.6638,-85.3203 to DataFrame.
# Added 33.5312,-84.3545 to DataFrame.
# Added 31.5253,-87.9277 to DataFrame.
# Added 35.94194,-85.78917 to DataFrame.
# Added 33.0537,-85.0318 to DataFrame.
# Added 32.6592,-85.4492 to DataFrame.
# Added 37.11667,-84.61667 to DataFrame.
# Added 36.6122,-88.3083 to DataFrame.
# Added 33.4029,-82.6222 to DataFrame.
# Added 32.0467,-84.3711 to DataFrame.
# Added 34.2286,-84.1281 to DataFrame.
# Added 35.9067,-85.4751 to DataFrame.
# Added 32.10833,-83.82889 to DataFrame.
# Added 35.3696,-84.2999 to DataFrame.
# Added 35.1342,-86.5419 to DataFrame.
# Added 35.55722,-87.20194000000001 to DataFrame.
# Added 33.3263,-86.7562 to DataFrame.
# Added 33.9478,-86.4692 to DataFrame.
# Added 33.6906,-86.685 to DataFrame.
# Added 37.8725,-82.5195 to DataFrame.
# Added 34.28778,-85.96806 to DataFrame.
# Added 36.76,-88.1386 to DataFrame.
# Added 36.5516,-84.1728 to DataFrame.
# Added 36.15,-84.7283 to DataFrame.
# Added 35.9204,-86.3727 to DataFrame.
# Added 37.34167,-83.47055999999999 to DataFrame.
# Added 31.0286,-84.8911 to DataFrame.
# Added 36.62389,-87.41944000000001 to DataFrame.
# Added 35.9327,-88.7268 to DataFrame.
# Added 33.5619,-82.3389 to DataFrame.
# Added 33.5972,-85.0805 to DataFrame.
# Added 32.66667,-85.91667 to DataFrame.
# Added 31.841390000000004,-82.37556 to DataFrame.
# Added 35.18417,-87.04222 to DataFrame.
# Added 37.1852,-86.6335 to DataFrame.
# Added 36.235,-88.0908 to DataFrame.
# Added 37.6527,-84.7708 to DataFrame.
# Added 37.2166,-86.8936 to DataFrame.
# Added 34.9047,-83.4127 to DataFrame.
# Added 32.6094,-83.6163 to DataFrame.
# Added 37.591390000000004,-83.31444 to DataFrame.
# Added 33.77917,-84.52139 to DataFrame.
# Added 33.9664,-83.2911 to DataFrame.
# Added 35.6047,-87.8408 to DataFrame.
# Added 36.0827,-85.82600000000001 to DataFrame.
# Added 35.7875,-84.2622 to DataFrame.
# Added 32.929,-87.1898 to DataFrame.
# Added 35.6763,-84.8547 to DataFrame.
# Added 38.3354,-82.9075 to DataFrame.
# Added 34.6736,-86.0536 to DataFrame.
# Added 33.911,-87.8469 to DataFrame.
# Added 38.202220000000004,-84.8825 to DataFrame.
# Added 33.7392,-88.1275 to DataFrame.
# Added 31.9155,-86.3115 to DataFrame.
# Added 33.5721,-86.0573 to DataFrame.
# Added 35.9417,-86.8685 to DataFrame.
# Added 34.9203,-85.2711 to DataFrame.
# Added 32.867,-84.2654 to DataFrame.
# Added 30.913890000000002,-83.86111 to DataFrame.
# Added 31.2644,-83.2391 to DataFrame.
# Added 33.35528,-84.56694 to DataFrame.
# Added 30.884,-87.7852 to DataFrame.
# Added 35.7197,-86.9654 to DataFrame.
# Added 36.4161,-82.9838 to DataFrame.
# Added 34.2851,-85.9621 to DataFrame.
# Added 33.7091,-87.8152 to DataFrame.
# Added 32.4567,-87.2422 to DataFrame.
# Added 35.6391,-85.3586 to DataFrame.
# Added 36.0138,-85.1345 to DataFrame.
# Added 30.8078,-81.4596 to DataFrame.
# Added 34.5653,-85.6171 to DataFrame.
# Added 35.65583,-88.00639 to DataFrame.
# Added 36.883,-88.9961 to DataFrame.
# Added 37.1318,-86.1481 to DataFrame.
# Added 31.41556,-87.04417 to DataFrame.
# Added 32.2843,-83.4681 to DataFrame.
# Added 31.4449,-86.9532 to DataFrame.
# Added 30.9591,-81.7071 to DataFrame.
# Added 37.5316,-85.735 to DataFrame.
# Added 36.3776,-85.3365 to DataFrame.
# Added 32.6875,-84.5198 to DataFrame.
# Added 35.713609999999996,-88.56083000000001 to DataFrame.
# Added 34.6602,-87.3462 to DataFrame.
# Added 30.5485,-87.8757 to DataFrame.
# Added 34.3337,-86.3156 to DataFrame.
# Added 34.1954,-86.7963 to DataFrame.
# Added 35.6502,-88.3904 to DataFrame.
# Added 31.951390000000004,-85.12889 to DataFrame.
# Added 31.0425,-86.31166999999999 to DataFrame.
# Added 36.855,-86.8883 to DataFrame.
# Added 34.27194,-83.83028 to DataFrame.
# Added 35.9675,-88.0458 to DataFrame.
# Added 35.4442,-88.7244 to DataFrame.
# Added 31.91722,-87.73472 to DataFrame.
# Added 37.3577,-83.7705 to DataFrame.
# Added 35.7522,-87.7958 to DataFrame.
# Added 36.29806,-86.26306 to DataFrame.
# Added 35.655,-83.4411 to DataFrame.
# Added 36.465,-83.5603 to DataFrame.
# Added 34.1409,-82.8551 to DataFrame.
# Added 38.18472,-84.90333000000001 to DataFrame.
# Added 31.30889,-86.39389 to DataFrame.
# Added 32.0112,-85.0901 to DataFrame.
# Added 33.3996,-84.915 to DataFrame.
# Added 35.51583,-86.0875 to DataFrame.
# Added 37.9161,-85.6572 to DataFrame.
# Added 34.4535,-87.7104 to DataFrame.
# Added 36.4511,-86.6455 to DataFrame.
# Added 31.2738,-81.9197 to DataFrame.
# Added 34.6941,-85.9998 to DataFrame.
# Added 32.7169,-87.6226 to DataFrame.
# Added 34.7728,-87.6399 to DataFrame.
# Added 32.8516,-86.6115 to DataFrame.
# Added 32.8369,-88.1374 to DataFrame.
# Added 36.2291,-86.318 to DataFrame.
# Added 34.6525,-86.94528000000001 to DataFrame.
# Added 31.8814,-86.2503 to DataFrame.
# Added 32.5992,-85.4653 to DataFrame.
# Added 31.2239,-84.5554 to DataFrame.
# Added 35.6394,-84.665 to DataFrame.
# Added 35.7103,-88.8223 to DataFrame.
# Added 37.79278,-86.2325 to DataFrame.
# Added 35.836,-84.69200000000001 to DataFrame.
# Added 37.2669,-83.6501 to DataFrame.
# Added 38.7744,-84.9672 to DataFrame.
# Added 31.7633,-84.1869 to DataFrame.
# Added 31.3127,-84.4706 to DataFrame.
# Added 33.2119,-87.6161 to DataFrame.
# Added 31.1923,-84.4465 to DataFrame.
# Added 34.6891,-86.8819 to DataFrame.
# Added 35.7178,-89.4986 to DataFrame.
# Added 37.46667,-83.66056 to DataFrame.
# Added 33.285,-86.3431 to DataFrame.
# Added 36.3805,-84.8744 to DataFrame.
# Added 35.6213,-88.8456 to DataFrame.
# Added 37.5733,-84.2908 to DataFrame.
# Added 33.4163,-86.135 to DataFrame.
# Added 36.213,-84.0602 to DataFrame.
# Added 36.325,-87.7886 to DataFrame.
# Added 35.2983,-86.3631 to DataFrame.
# Added 36.2872,-88.2958 to DataFrame.
# Added 37.3475,-87.5238 to DataFrame.
# Added 37.6497,-86.4308 to DataFrame.
# Added 36.4259,-84.94200000000001 to DataFrame.
# Added 33.3952,-87.0077 to DataFrame.
# Added 31.182,-87.439 to DataFrame.
# Added 35.7635,-86.9321 to DataFrame.
# Added 35.1615,-86.0315 to DataFrame.
# Added 38.0945,-84.7465 to DataFrame.
# Added 35.9833,-83.2008 to DataFrame.
# Added 32.6089,-85.0756 to DataFrame.
# Added 36.3444,-88.8636 to DataFrame.
# Added 34.5528,-86.445 to DataFrame.
# Added 34.1736,-86.8133 to DataFrame.
# Added 37.495,-85.1516 to DataFrame.
# Added 36.7458,-86.2258 to DataFrame.
# Added 37.85889,-87.40861 to DataFrame.
# Added 30.5468,-87.8807 to DataFrame.
# Added 31.8709,-85.4501 to DataFrame.
# Added 34.8544,-83.9444 to DataFrame.
# Added 33.8705,-83.1135 to DataFrame.
# Added 35.0097,-85.3444 to DataFrame.
# Added 34.4546,-85.39 to DataFrame.
# Added 37.2504,-86.2325 to DataFrame.
# Added 35.5567,-87.5414 to DataFrame.
# Added 34.3328,-84.4703 to DataFrame.
# Added 37.955999999999996,-86.1162 to DataFrame.
# Added 36.3661,-85.6552 to DataFrame.
# Added 33.158,-85.2911 to DataFrame.
# Added 33.7837,-83.3896 to DataFrame.
# Added 37.8176,-82.7882 to DataFrame.
# Added 37.0683,-88.7724 to DataFrame.
# Added 38.4946,-83.0183 to DataFrame.
# Added 38.0316,-83.3917 to DataFrame.
# Added 37.9414,-83.3018 to DataFrame.
# Added 36.8425,-85.5244 to DataFrame.
# Added 38.3422,-83.1036 to DataFrame.
# Added 32.5193,-87.88 to DataFrame.
# Added 34.3347,-86.3294 to DataFrame.
# Added 31.4461,-83.4767 to DataFrame.
# Added 34.2553,-87.1814 to DataFrame.
# Added 33.0125,-82.3914 to DataFrame.
# Added 34.3344,-86.3297 to DataFrame.
# Added 36.48194,-87.86278 to DataFrame.
# Added 36.1056,-82.8436 to DataFrame.
# Added 32.5181,-84.9378 to DataFrame.
# Added 34.78889,-87.53944 to DataFrame.
# Added 36.8491,-87.5205 to DataFrame.
# Added 35.5497,-89.7 to DataFrame.
# Added 35.7977,-89.1176 to DataFrame.
# Added 31.168059999999997,-84.76639 to DataFrame.
# Added 34.48833,-87.29889 to DataFrame.
# Added 37.6336,-83.7161 to DataFrame.
# Added 36.5027,-84.5308 to DataFrame.
# Added 34.2413,-85.1584 to DataFrame.
# Added 33.1272,-88.155 to DataFrame.
# Added 33.4522,-84.0678 to DataFrame.
# Added 35.4322,-84.5833 to DataFrame.
# Added 38.4537,-82.6131 to DataFrame.
# Added 36.10333,-87.11528 to DataFrame.
# Added 35.1152,-89.9924 to DataFrame.
# Added 37.5319,-87.2669 to DataFrame.
# Added 34.5181,-83.5286 to DataFrame.
# Added 37.4533,-86.9116 to DataFrame.
# Added 37.7558,-87.6455 to DataFrame.
# Added 38.12278,-83.53278 to DataFrame.
# Added 35.6723,-85.781 to DataFrame.
# Added 36.065,-86.4175 to DataFrame.
# Added 31.8878,-82.5808 to DataFrame.
# Added 36.0749,-87.3959 to DataFrame.
# Added 37.5108,-86.2891 to DataFrame.
# Added 30.74,-82.1278 to DataFrame.
# Added 36.1075,-85.5033 to DataFrame.
# Added 35.9902,-86.7786 to DataFrame.
# Added 35.4721,-84.9957 to DataFrame.
# Added 32.2024,-82.3305 to DataFrame.
# Added 31.5075,-81.8628 to DataFrame.
# Added 33.2725,-86.83361 to DataFrame.
# Added 33.8533,-84.5783 to DataFrame.
# Added 34.15,-85.6846 to DataFrame.
# Added 36.0027,-88.4252 to DataFrame.
# Added 32.9452,-85.948 to DataFrame.
# Added 35.5894,-89.2586 to DataFrame.
# Added 31.985,-83.77472 to DataFrame.
# Added 34.6646,-83.7342 to DataFrame.
# Added 38.115,-85.6444 to DataFrame.
# Added 35.0761,-89.743 to DataFrame.
# Added 37.5787,-83.7659 to DataFrame.
# Added 35.80917,-85.64166999999999 to DataFrame.
# Added 35.6031,-83.7781 to DataFrame.
# Added 34.5569,-86.9502 to DataFrame.
# Added 34.5786,-83.3319 to DataFrame.
# Added 34.0678,-86.791 to DataFrame.
# Added 32.9069,-85.4336 to DataFrame.
# Added 33.6483,-85.6005 to DataFrame.
# Added 31.7901,-86.0004 to DataFrame.
# Added 31.1449,-87.0518 to DataFrame.
# Added 32.9745,-82.8045 to DataFrame.
# Added 34.9093,-87.2746 to DataFrame.
# Added 32.3349,-86.9787 to DataFrame.
# Added 36.34083,-86.8275 to DataFrame.
# Added 37.8299,-84.0347 to DataFrame.
# Added 34.7752,-86.9508 to DataFrame.
# Added 33.875,-84.30221999999999 to DataFrame.
# Added 37.4902,-84.4375 to DataFrame.
# Added 33.178329999999995,-86.78166999999999 to DataFrame.
# Added 36.0236,-84.2375 to DataFrame.
# Added 34.0966,-87.9913 to DataFrame.
# Added 30.8055,-83.2736 to DataFrame.
# Added 31.2975,-85.8996 to DataFrame.
# Added 34.3519,-82.93 to DataFrame.
# Added 31.3625,-85.3397 to DataFrame.
# Added 34.3388,-82.8341 to DataFrame.
# Added 31.3071,-86.5226 to DataFrame.
# Added 37.6798,-85.8761 to DataFrame.
# Added 32.6328,-81.7756 to DataFrame.
# Added 31.8814,-87.7367 to DataFrame.
# Added 36.8582,-83.3302 to DataFrame.
# Added 34.123059999999995,-84.84861 to DataFrame.
# Added 31.7901,-86.6087 to DataFrame.
# Added 33.2941,-85.7788 to DataFrame.
# Added 36.2455,-85.945 to DataFrame.
# Added 35.8575,-84.5278 to DataFrame.
# Added 32.7019,-87.5815 to DataFrame.
# Added 35.6878,-83.5373 to DataFrame.
# Added 37.9589,-82.7463 to DataFrame.
# Added 32.816,-86.60417 to DataFrame.
# Added 35.1298,-89.8037 to DataFrame.
# Added 36.8977,-86.1247 to DataFrame.
# Added 36.0148,-85.1313 to DataFrame.
# Added 36.247,-86.5631 to DataFrame.
# Added 38.3769,-84.303 to DataFrame.
# Added 36.5193,-86.0299 to DataFrame.
# Added 32.8236,-85.6561 to DataFrame.
# Added 31.4715,-88.2504 to DataFrame.
# Added 34.6996,-83.7261 to DataFrame.
# Added 32.8294,-83.2389 to DataFrame.
# Added 33.8722,-83.5358 to DataFrame.
# Added 34.2314,-87.6352 to DataFrame.
# Added 36.0519,-88.0828 to DataFrame.
# Added 36.5194,-82.5275 to DataFrame.
# Added 35.8318,-87.4219 to DataFrame.
# Added 35.1131,-89.2122 to DataFrame.
# Added 36.12222,-83.47389 to DataFrame.
# Added 34.2625,-83.4895 to DataFrame.
# Added 33.59722,-83.84361 to DataFrame.
# Added 35.9296,-83.5983 to DataFrame.
# Added 32.7127,-82.5415 to DataFrame.
# Added 32.4715,-87.2313 to DataFrame.
# Added 37.0055,-85.0616 to DataFrame.
# Added 34.1924,-86.7972 to DataFrame.
# Added 32.0306,-84.2461 to DataFrame.
# Added 30.8696,-84.2174 to DataFrame.
# Added 35.96889,-87.13639 to DataFrame.
# Added 31.1681,-81.5022 to DataFrame.
# Added 31.938000000000002,-83.3077 to DataFrame.
# Added 37.6177,-86.5044 to DataFrame.
# Added 38.0408,-84.6058 to DataFrame.
# Added 38.1811,-85.7391 to DataFrame.
# Added 38.2186,-83.14299999999999 to DataFrame.
# Added 31.2514,-82.3128 to DataFrame.
# Added 36.1142,-87.7419 to DataFrame.
# Added 35.1647,-88.5994 to DataFrame.
# Added 31.8717,-81.6289 to DataFrame.
# Added 31.8966,-85.0375 to DataFrame.
# Added 34.4406,-85.7236 to DataFrame.
# Added 39.0444,-84.6724 to DataFrame.
# Added 36.17222,-87.18056 to DataFrame.
# Added 35.3684,-85.7014 to DataFrame.
# Added 31.5338,-84.1488 to DataFrame.
# Added 32.5905,-86.2102 to DataFrame.
# Added 38.22806,-85.66360999999999 to DataFrame.
# Added 33.0726,-82.0061 to DataFrame.
# Added 36.5409,-85.4596 to DataFrame.
# Added 34.9786,-85.8008 to DataFrame.
# Added 34.0219,-85.9878 to DataFrame.
# Added 34.4416,-83.5161 to DataFrame.
# Added 32.397220000000004,-82.08194 to DataFrame.
# Added 34.3006,-83.86 to DataFrame.
# Added 36.4975,-87.33556 to DataFrame.
# Added 35.8984,-83.9569 to DataFrame.
# Added 36.58028,-85.12556 to DataFrame.
# Added 32.8347,-88.1341 to DataFrame.
# Added 33.2053,-86.2114 to DataFrame.
# Added 32.5161,-84.9422 to DataFrame.
# Added 30.7825,-83.27667 to DataFrame.
# Added 36.4527,-89.3027 to DataFrame.
# Added 35.345279999999995,-86.20889 to DataFrame.
# Added 35.2028,-85.9172 to DataFrame.
# Added 36.5471,-87.3353 to DataFrame.
# Added 31.988000000000003,-81.9522 to DataFrame.
# Added 37.35417,-84.33694 to DataFrame.
# Added 36.3211,-87.2218 to DataFrame.
# Added 35.35,-89.86667 to DataFrame.
# Added 31.48889,-82.82056 to DataFrame.
# Added 36.86667,-84.8275 to DataFrame.
# Added 37.0147,-88.2677 to DataFrame.
# Added 32.879,-85.1809 to DataFrame.
# Added 31.3167,-85.45 to DataFrame.
# Added 30.62639,-88.06806 to DataFrame.
# Added 33.46694,-82.03860999999999 to DataFrame.
# Added 33.9048,-87.3154 to DataFrame.
# Added 33.0831,-83.2498 to DataFrame.
# Added 30.8264,-82.3606 to DataFrame.
# Added 30.2505,-88.0775 to DataFrame.
# Added 31.0583,-87.0549 to DataFrame.
# Added 32.26,-86.21799999999999 to DataFrame.
# Added 32.375,-81.6731 to DataFrame.
# Added 34.5069,-84.0207 to DataFrame.
# Added 31.0767,-82.8003 to DataFrame.
# Added 31.1413,-87.0486 to DataFrame.
# Added 36.3925,-89.0317 to DataFrame.
# Added 37.2571,-85.5012 to DataFrame.
# Added 32.4419,-85.8889 to DataFrame.
# Added 35.2897,-85.4736 to DataFrame.
# Added 36.10139,-87.28472 to DataFrame.
# Added 32.8753,-82.2156 to DataFrame.
# Added 35.49222,-86.4775 to DataFrame.
# Added 34.5859,-83.7658 to DataFrame.
# Added 35.7047,-86.4869 to DataFrame.
# Added 31.615,-85.0494 to DataFrame.
# Added 33.3329,-83.6975 to DataFrame.
# Added 31.03833,-85.87083 to DataFrame.
# Added 31.3781,-82.1292 to DataFrame.
# Added 36.1422,-82.4261 to DataFrame.
# Added 33.988,-84.7475 to DataFrame.
# Added 31.3972,-81.2811 to DataFrame.
# Added 34.2834,-86.9142 to DataFrame.
# Added 35.2622,-88.9891 to DataFrame.
# Added 31.8453,-83.9409 to DataFrame.
# Added 34.165,-84.73 to DataFrame.
# Added 35.5983,-85.1939 to DataFrame.
# Added 36.0968,-86.1397 to DataFrame.
# Added 35.593,-88.9167 to DataFrame.
# Added 32.6847,-83.6527 to DataFrame.
# Added 36.2836,-88.7063 to DataFrame.
# Added 34.4758,-84.4461 to DataFrame.
# Added 33.2119,-87.6161 to DataFrame.
# Added 36.9647,-86.4238 to DataFrame.
# Added 31.767220000000002,-84.79306 to DataFrame.
# Added 37.2791,-86.2491 to DataFrame.
# Added 30.5654,-87.7018 to DataFrame.
# Added 36.8825,-83.8819 to DataFrame.
# Added 36.4583,-86.324 to DataFrame.
# Added 36.0002,-89.4094 to DataFrame.
# Added 37.0486,-88.0727 to DataFrame.
# Added 36.37556,-86.18083 to DataFrame.
# Added 34.34778,-85.16111 to DataFrame.
# Added 32.5811,-88.1897 to DataFrame.
# Added 37.7858,-84.7077 to DataFrame.
# Added 37.8194,-85.3847 to DataFrame.
# Added 36.8276,-85.8975 to DataFrame.
# Added 35.7285,-86.6435 to DataFrame.
# Finished Processing

# %%
# Check if any json requests were unsuccessful
missing_stations
# Out:
# []

# %%
# Check for any empty county/zip entries
stations.loc[stations["COUNTY"] == ""]
# Out:
# Empty DataFrame
# Columns: [STATION, NAME, LATITUDE, LONGITUDE, STATE, COORD, COUNTY, ZIP]
# Index: []

# %%
# Retry API calls which didn't work

# Create empty list to store any API calls that don't work
missing_stations_2 = []

for entry in missing_stations:
    coord = entry['COORD']
    # Assemble url and make API call based on coordinates
    url = f'https://maps.googleapis.com/maps/api/geocode/json?latlng={coord}&key={gkey}'
    response = requests.get(url)
    geocoding = response.json()
    
    try:
        # Find zipcode and county within JSON response
        for dict in geocoding['results'][0]['address_components']:
            if 'administrative_area_level_2' in dict['types']:
                county = dict['long_name']
            if 'postal_code' in dict['types']:
                zipcode = dict['long_name']
        # Add zipcode and county to dataframe
        stations.loc[stations['COORD'] == coord, 'COUNTY'] = county
        stations.loc[stations['COORD'] == coord, 'ZIP'] = zipcode

        print(f'Added {coord} to DataFrame.')
    
    except:
        # Store any problematic coordinates
        missing_dict = {}
        missing_dict['JSON'] = geocoding
        missing_dict['COORD'] = coord
        missing_stations_2.append(missing_dict)
        print(f'Could not add {coord} to DataFrame')

print('Finished Processing')
# Out:
# Added 33.46167,-80.85806 to DataFrame.
# Added 34.7055,-79.5683 to DataFrame.
# Added 33.3169,-79.3227 to DataFrame.
# Finished Processing

# %%
# Preview DataFrame
stations.loc[stations['COUNTY'] != '']
# Out:
#             STATION                            NAME  LATITUDE  LONGITUDE  \
# 366     USC00461324     CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# 732     USC00442009                   CORBIN, VA US   38.2022   -77.3747
# 1098    USC00440187      AMELIA COURTHOUSE 1, VA US   37.3451   -77.9781
# 1464    USC00442245                 DANVILLE, VA US   36.5869   -79.3886
# 2196    USC00466212  MORGANTOWN LOCK AND DAM, WV US   39.6203   -79.9698
# ...             ...                             ...       ...        ...
# 214083  USC00014798               LIVINGSTON, AL US   32.5811   -88.1897
# 215180  USC00152214                  DIX DAM, KY US   37.7858   -84.7077
# 215912  USC00150397            BARDSTOWN 5 E, KY US   37.8194   -85.3847
# 216278  USC00152575                   ETOILE, KY US   36.8276   -85.8975
# 217010  USC00402711          EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
#
#        STATE             COORD             COUNTY    ZIP
# 366       WV  39.5064,-78.3158      Morgan County  25411
# 732       VA  38.2022,-77.3747    Caroline County  22580
# 1098      VA  37.3451,-77.9781      Amelia County  23002
# 1464      VA  36.5869,-79.3886      Amelia County  24541
# 2196      WV  39.6203,-79.9698  Monongalia County  26501
# ...      ...               ...                ...    ...
# 214083    AL  32.5811,-88.1897      Sumter County  35470
# 215180    KY  37.7858,-84.7077      Mercer County  40330
# 215912    KY  37.8194,-85.3847      Nelson County  40004
# 216278    KY  36.8276,-85.8975      Barren County  42141
# 217010    TN  35.7285,-86.6435  Rutherford County  37060
#
# [932 rows x 8 columns]

# %%
missing_stations_2
# Out:
# []

# %%
# Check that there are no missing values
stations.count()
# Out:
# STATION      932
# NAME         932
# LATITUDE     932
# LONGITUDE    932
# STATE        932
# COORD        932
# COUNTY       932
# ZIP          932
# dtype: int64

# %%
# Store station metadata in csv file
stations.to_csv('../data/stations-metadata.csv', index=False)

# %%
# Merge station metadata with initial data
stations_subset = stations[['NAME', 'COUNTY', 'ZIP']]
df_clean_3 = pd.merge(df_clean_2, stations_subset, on='NAME')
df_clean_3
# Out:
#             STATION                         NAME  LATITUDE  LONGITUDE  \
# 0       USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# 1       USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# 2       USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# 3       USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# 4       USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158
# ...             ...                          ...       ...        ...
# 341114  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
# 341115  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
# 341116  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
# 341117  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
# 341118  USC00402711       EAGLEVILLE 1 SW, TN US   35.7285   -86.6435
#
#         ELEVATION   DATE  DLY-TAVG-NORMAL  DLY-TAVG-STDDEV  DLY-TMAX-NORMAL  \
# 0           289.6  01-01             29.8             10.3             38.6
# 1           289.6  01-02             29.7             10.3             38.5
# 2           289.6  01-03             29.7             10.4             38.4
# 3           289.6  01-04             29.6             10.4             38.4
# 4           289.6  01-05             29.5             10.5             38.3
# ...           ...    ...              ...              ...              ...
# 341114      243.8  12-27             38.3              NaN             47.8
# 341115      243.8  12-28             38.1              NaN             47.7
# 341116      243.8  12-29             38.0              NaN             47.6
# 341117      243.8  12-30             37.9              NaN             47.4
# 341118      243.8  12-31             37.8              NaN             47.3
#
#         DLY-TMAX-STDDEV  DLY-TMIN-NORMAL  DLY-TMIN-STDDEV STATE  \
# 0                  11.8             21.0             10.4    WV
# 1                  11.8             20.9             10.5    WV
# 2                  11.9             20.9             10.6    WV
# 3                  11.9             20.8             10.6    WV
# 4                  11.9             20.8             10.7    WV
# ...                 ...              ...              ...   ...
# 341114              NaN             28.7              NaN    TN
# 341115              NaN             28.6              NaN    TN
# 341116              NaN             28.5              NaN    TN
# 341117              NaN             28.4              NaN    TN
# 341118              NaN             28.3              NaN    TN
#
#                    COUNTY    ZIP
# 0           Morgan County  25411
# 1           Morgan County  25411
# 2           Morgan County  25411
# 3           Morgan County  25411
# 4           Morgan County  25411
# ...                   ...    ...
# 341114  Rutherford County  37060
# 341115  Rutherford County  37060
# 341116  Rutherford County  37060
# 341117  Rutherford County  37060
# 341118  Rutherford County  37060
#
# [341119 rows x 15 columns]

# %%
# Store cleaned dataset in csv file
df_clean_3.to_csv('../data/se-weather-cleaned.csv', index=False)

# %% [markdown]
# ## Formatting for MongoDB

# %%
weather = pd.read_csv("../data/se-weather-cleaned.csv")
weather.head()
# Out:
#        STATION                         NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 1  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 2  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 3  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 4  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
#
#     DATE  DLY-TAVG-NORMAL  DLY-TAVG-STDDEV  DLY-TMAX-NORMAL  DLY-TMAX-STDDEV  \
# 0  01-01             29.8             10.3             38.6             11.8
# 1  01-02             29.7             10.3             38.5             11.8
# 2  01-03             29.7             10.4             38.4             11.9
# 3  01-04             29.6             10.4             38.4             11.9
# 4  01-05             29.5             10.5             38.3             11.9
#
#    DLY-TMIN-NORMAL  DLY-TMIN-STDDEV STATE         COUNTY    ZIP
# 0             21.0             10.4    WV  Morgan County  25411
# 1             20.9             10.5    WV  Morgan County  25411
# 2             20.9             10.6    WV  Morgan County  25411
# 3             20.8             10.6    WV  Morgan County  25411
# 4             20.8             10.7    WV  Morgan County  25411

# %%
weather.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE',
#        'DLY-TAVG-NORMAL', 'DLY-TAVG-STDDEV', 'DLY-TMAX-NORMAL',
#        'DLY-TMAX-STDDEV', 'DLY-TMIN-NORMAL', 'DLY-TMIN-STDDEV', 'STATE',
#        'COUNTY', 'ZIP'],
#       dtype='object')

# %%
stations = pd.read_csv("../data/stations-metadata.csv")
stations.head()
# Out:
#        STATION                            NAME  LATITUDE  LONGITUDE STATE  \
# 0  USC00461324     CACAPON STATE PARK 2, WV US   39.5064   -78.3158    WV
# 1  USC00442009                   CORBIN, VA US   38.2022   -77.3747    VA
# 2  USC00440187      AMELIA COURTHOUSE 1, VA US   37.3451   -77.9781    VA
# 3  USC00442245                 DANVILLE, VA US   36.5869   -79.3886    VA
# 4  USC00466212  MORGANTOWN LOCK AND DAM, WV US   39.6203   -79.9698    WV
#
#               COORD             COUNTY    ZIP
# 0  39.5064,-78.3158      Morgan County  25411
# 1  38.2022,-77.3747    Caroline County  22580
# 2  37.3451,-77.9781      Amelia County  23002
# 3  36.5869,-79.3886      Amelia County  24541
# 4  39.6203,-79.9698  Monongalia County  26501

# %%
stations.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'STATE', 'COORD', 'COUNTY',
#        'ZIP'],
#       dtype='object')

# %%
zips = pd.read_csv("../data/zipcodes_master.csv")
zips.head()
# Out:
#      ZIP STATE  LATITUDE  LONGITUDE                  CLOSEST-STATION
# 0  26031    WV     40.01     -80.73                  WHEELING, WV US
# 1  26032    WV     40.20     -80.56  WHEELING OHIO CO AIRPORT, WV US
# 2  26033    WV     39.82     -80.57               MOUNDSVILLE, WV US
# 3  26034    WV     40.61     -80.56  WHEELING OHIO CO AIRPORT, WV US
# 4  26035    WV     40.34     -80.55  WHEELING OHIO CO AIRPORT, WV US

# %%
zips_new = zips.rename(columns={'Zipcode': 'ZIP', 'State': 'STATE', 'Lat': 'LATITUDE', 'Long': 'LONGITUDE', 'Closest Weather Station': 'CLOSEST-STATION'})

# %%
zips_new.columns
# Out:
# Index(['ZIP', 'STATE', 'LATITUDE', 'LONGITUDE', 'CLOSEST-STATION'], dtype='object')

# %%
zips_new.to_csv("../data/zipcodes_master.csv", index=False)

# %% [markdown]
# ## Add a faux year to each calendar date
# *Allows for date filtering in MongoDB

# %%
# Read in full dataset
df = pd.read_csv("../data/se-weather-cleaned.csv")
df.head()
# Out:
#        STATION                         NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 1  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 2  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 3  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 4  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
#
#     DATE  DLY-TAVG-NORMAL  DLY-TAVG-STDDEV  DLY-TMAX-NORMAL  DLY-TMAX-STDDEV  \
# 0  01-01             29.8             10.3             38.6             11.8
# 1  01-02             29.7             10.3             38.5             11.8
# 2  01-03             29.7             10.4             38.4             11.9
# 3  01-04             29.6             10.4             38.4             11.9
# 4  01-05             29.5             10.5             38.3             11.9
#
#    DLY-TMIN-NORMAL  DLY-TMIN-STDDEV STATE         COUNTY    ZIP DATE_FILTER
# 0             21.0             10.4    WV  Morgan County  25411  01-01-2008
# 1             20.9             10.5    WV  Morgan County  25411  01-02-2008
# 2             20.9             10.6    WV  Morgan County  25411  01-03-2008
# 3             20.8             10.6    WV  Morgan County  25411  01-04-2008
# 4             20.8             10.7    WV  Morgan County  25411  01-05-2008

# %%
# This function takes in the station name as a string and extracts the state that the station is in
# This function returns the state two-letter code as a string
def createDate(string):
    date = string + '-2008'
    return date

# %%
df['DATE_FILTER'] = df['DATE'].apply(createDate)

# %%
df.head()
# Out:
#        STATION                         NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 1  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 2  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 3  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 4  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
#
#     DATE  DLY-TAVG-NORMAL  DLY-TAVG-STDDEV  DLY-TMAX-NORMAL  DLY-TMAX-STDDEV  \
# 0  01-01             29.8             10.3             38.6             11.8
# 1  01-02             29.7             10.3             38.5             11.8
# 2  01-03             29.7             10.4             38.4             11.9
# 3  01-04             29.6             10.4             38.4             11.9
# 4  01-05             29.5             10.5             38.3             11.9
#
#    DLY-TMIN-NORMAL  DLY-TMIN-STDDEV STATE         COUNTY    ZIP DATE_FILTER
# 0             21.0             10.4    WV  Morgan County  25411  01-01-2008
# 1             20.9             10.5    WV  Morgan County  25411  01-02-2008
# 2             20.9             10.6    WV  Morgan County  25411  01-03-2008
# 3             20.8             10.6    WV  Morgan County  25411  01-04-2008
# 4             20.8             10.7    WV  Morgan County  25411  01-05-2008

# %%
# Store cleaned dataset in csv file
df.to_csv('../data/se-weather-cleaned.csv', index=False)

# %% [markdown]
# ## Make dataset leaner to save space in MongoDB

# %%
# Read in full dataset
df = pd.read_csv("../data/se-weather-cleaned.csv")
df.head()
# Out:
#        STATION                         NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 1  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 2  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 3  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 4  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
#
#     DATE  DLY-TAVG-NORMAL  DLY-TAVG-STDDEV  DLY-TMAX-NORMAL  DLY-TMAX-STDDEV  \
# 0  01-01             29.8             10.3             38.6             11.8
# 1  01-02             29.7             10.3             38.5             11.8
# 2  01-03             29.7             10.4             38.4             11.9
# 3  01-04             29.6             10.4             38.4             11.9
# 4  01-05             29.5             10.5             38.3             11.9
#
#    DLY-TMIN-NORMAL  DLY-TMIN-STDDEV STATE         COUNTY    ZIP DATE_FILTER
# 0             21.0             10.4    WV  Morgan County  25411  01-01-2008
# 1             20.9             10.5    WV  Morgan County  25411  01-02-2008
# 2             20.9             10.6    WV  Morgan County  25411  01-03-2008
# 3             20.8             10.6    WV  Morgan County  25411  01-04-2008
# 4             20.8             10.7    WV  Morgan County  25411  01-05-2008

# %%
del df['DLY-TAVG-STDDEV']
del df['DLY-TMAX-STDDEV']
del df['DLY-TMIN-STDDEV']
df.head()
# Out:
#        STATION                         NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 1  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 2  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 3  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
# 4  USC00461324  CACAPON STATE PARK 2, WV US   39.5064   -78.3158      289.6
#
#     DATE  DLY-TAVG-NORMAL  DLY-TMAX-NORMAL  DLY-TMIN-NORMAL STATE  \
# 0  01-01             29.8             38.6             21.0    WV
# 1  01-02             29.7             38.5             20.9    WV
# 2  01-03             29.7             38.4             20.9    WV
# 3  01-04             29.6             38.4             20.8    WV
# 4  01-05             29.5             38.3             20.8    WV
#
#           COUNTY    ZIP DATE_FILTER
# 0  Morgan County  25411  01-01-2008
# 1  Morgan County  25411  01-02-2008
# 2  Morgan County  25411  01-03-2008
# 3  Morgan County  25411  01-04-2008
# 4  Morgan County  25411  01-05-2008

# %%
# Store cleaned dataset in csv file
df.to_csv('../data/se-weather-cleaned-lean.csv', index=False)

# %% [markdown]
# ## Inaccurate Geocoding (not in deployed version)

# %%
# Dependencies
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
# Set up reverse geocoding function
locator = Nominatim(user_agent='myGeocoder', timeout=10)
rgeocode = RateLimiter(locator.reverse, min_delay_seconds=0.001)

# Create columns for county and zip code
stations['COUNTY'] = ''
stations['ZIP'] = ''

# Pull county and zip code for each station
for index, row in stations.iterrows():
    try:
        coord = row['COORD']
        address = rgeocode(coord)
        county = address.raw['address']['county']
        zipcode = address.raw['address']['postcode']
        stations.loc[index, 'COUNTY'] = county
        stations.loc[index, 'ZIP'] = zipcode
        print(f"{row['NAME']} complete.")
    except:
        print(f"Cannot find {row['NAME']}.")
    
print('Reverse geocoding complete.')
# Out:
# Cannot find CACAPON STATE PARK 2, WV US.
# CORBIN, VA US complete.
# AMELIA COURTHOUSE 1, VA US complete.
# Cannot find DANVILLE, VA US.
# MORGANTOWN LOCK AND DAM, WV US complete.
# ROWLESBURG 1, WV US complete.
# HUNTINGTON SWG PLANT, WV US complete.
# LONDON LOCKS, WV US complete.
# BREAKS INTERSTATE PARK, VA US complete.
# BOSTON 4 SE, VA US complete.
# AMELIA 8 NE, VA US complete.
# CHARLESTON INTL. AIRPORT, SC US complete.
# MUSTOE 1 SW, VA US complete.
# SANDHILL RESEARCH, SC US complete.
# FLAT TOP, WV US complete.
# OCEANA NAS, VA US complete.
# GREENVILLE DOWNTOWN AIRPORT, SC US complete.
# COLUMBIA METROPOLITAN AIRPORT, SC US complete.
# FENTRESS NAVAL AUXILIARY FIELD, VA US complete.
# BUCKEYE, WV US complete.
# CHARLESTON WSFO, WV US complete.
# CLINTWOOD 1 W, VA US complete.
# SOUTH BOSTON, VA US complete.
# BIG STONE GAP, VA US complete.
# GREENBAY 3 NE, VA US complete.
# PULASKI 2 E, VA US complete.
# STONEWALL JACKSON DAM, WV US complete.
# FREDERICKSBURG SEWAGE, VA US complete.
# RIPLEY, WV US complete.
# WILLIAMSON, WV US complete.
# JOHN H KERR DAM, VA US complete.
# LEBANON, VA US complete.
# PIEDMONT RESEARCH STATION, VA US complete.
# KEYSER 2 SSW, WV US complete.
# SPARTANBURG 3 SSE, SC US complete.
# REMINGTON 2, VA US complete.
# BLUEFIELD, WV US complete.
# OAK HILL, WV US complete.
# NORTH, VA US complete.
# WAKEFIELD MUNICIPAL AIRPORT, VA US complete.
# GREELEYVILLE 5 N, SC US complete.
# PARR, SC US complete.
# ASHLAND HANOVER CO MUNICIPAL AIRPORT, VA US complete.
# NEWBERRY, SC US complete.
# QUANTICO MCAS, VA US complete.
# EFFINGHAM, SC US complete.
# ELKINS 21 ENE, WV US complete.
# Cannot find BIG MEADOWS, VA US.
# PEA RIDGE PSD, WV US complete.
# GRANTSVILLE 1 ESE, WV US complete.
# MARTINSBURG 2, WV US complete.
# LAWRENCEVILLE 3 E, VA US complete.
# Cannot find COOPERS ROCK STATE FOREST, WV US.
# NORFOLK INTERNATIONAL AIRPORT, VA US complete.
# BUCKHANNON, WV US complete.
# Cannot find KUMBRABOW, WV US.
# Cannot find GATHRIGHT DAM, VA US.
# NORFOLK SOUTH, VA US complete.
# TERRA ALTA NUMBER 1, WV US complete.
# WYTHEVILLE, VA US complete.
# BLUESTONE LAKE, WV US complete.
# CHESNEE 7 WSW, SC US complete.
# Cannot find SUTTON LAKE, WV US.
# Cannot find MCCLELLANVILLE 7 NE, SC US.
# PARKERSBURG, WV US complete.
# CHARLESTON YEAGER AIRPORT, WV US complete.
# FLORENCE REGIONAL AIRPORT, SC US complete.
# WASHINGTON REAGAN NATIONAL AIRPORT, VA US complete.
# Cannot find ROANOKE REGIONAL AIRPORT, VA US.
# RICHMOND INTERNATIONAL AIRPORT, VA US complete.
# SNOWSHOE, WV US complete.
# SOMERSET, VA US complete.
# CLEMSON UNIVERSITY, SC US complete.
# BUCHANAN, VA US complete.
# LEXINGTON, VA US complete.
# Cannot find BROOKGREEN GARDENS, SC US.
# MOUNDSVILLE, WV US complete.
# NORFOLK NAS, VA US complete.
# LOUISA, VA US complete.
# SALUDA, SC US complete.
# BAMBERG, SC US complete.
# ORANGEBURG MUNICIPAL AIRPORT, SC US complete.
# CHARLOTTESVILLE 2 SSE, VA US complete.
# DALE ENTERPRISE, VA US complete.
# CADES 4 W, SC US complete.
# ABINGDON 3 S, VA US complete.
# CHARLOTTESVILLE 2 W, VA US complete.
# ROCKY MOUNT, VA US complete.
# WHITE SULPHUR SPRINGS, WV US complete.
# GRNVL SPART INTERNATIONAL AIRPORT, SC US complete.
# LONGTOWN, SC US complete.
# DAVIS 3 SE, WV US complete.
# Cannot find BECKLEY RALEIGH CO AIRPORT, WV US.
# NORA 4 SSE, VA US complete.
# ELIZABETH, WV US complete.
# GLENVILLE, WV US complete.
# Cannot find MIDDLEBOURNE 3 ESE, WV US.
# PALMYRA 3 S, VA US complete.
# Cannot find NEWPORT NEWS INTERNATIONAL AIRPORT, VA US.
# WHEELING OHIO CO AIRPORT, WV US complete.
# HACKER VALLEY, WV US complete.
# CEDAR CREEK 2 E, SC US complete.
# COLUMBIA OWENS DOWNTOWN AIRPORT, SC US complete.
# Cannot find SANDYVILLE 9 NE, WV US.
# MONTICELLO, VA US complete.
# DRY CREEK, WV US complete.
# GRUNDY, VA US complete.
# CHARLOTTE COURT HOUSE, VA US complete.
# HUNTINGTON TRI STATE AIRPORT, WV US complete.
# WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US complete.
# WALLOPS ISLAND WALLOPS FLIGHT FACILITY, VA US complete.
# LONG CREEK, SC US complete.
# UNION 8 S, SC US complete.
# MADISON, VA US complete.
# CAPE CHARLES 5 ENE, VA US complete.
# BLUEFIELD MERCER CO AIRPORT, WV US complete.
# SUMMERVILLE 4 W, SC US complete.
# ROCK HILL YORK CO AIRPORT, SC US complete.
# GREENWOOD CO AIRPORT, SC US complete.
# CHARLOTTESVILLE ALBEMARLE AIRPORT, VA US complete.
# Cannot find CHERAW, SC US.
# MANNINGTON 8 WNW, WV US complete.
# EDINBURG, VA US complete.
# CHRISTIANSBURG, VA US complete.
# Cannot find WARRENTON 3 SE, VA US.
# BARNWELL 5 ENE, SC US complete.
# APPOMATTOX, VA US complete.
# PETERSBURG, WV US complete.
# SANDY RUN 3 ENE, SC US complete.
# PAINTER 2 W, VA US complete.
# WARSAW 2 NW, VA US complete.
# Cannot find EMPORIA 1 WNW, VA US.
# SANDY SPRINGS 2 NE, SC US complete.
# WINCHESTER 7 SE, VA US complete.
# R.D. BAILEY LAKE, WV US complete.
# MULLINS, SC US complete.
# MOOREFIELD 1 SSE, WV US complete.
# MOUNT NEBO 1 S, WV US complete.
# YORK 4 S, SC US complete.
# WINCHESTER, VA US complete.
# MONCKS CORNER 4 N, SC US complete.
# Cannot find FRANKLIN 2 NE, WV US.
# JOHNSTON 4 SW, SC US complete.
# FAIRMONT, WV US complete.
# ALLENDALE 2 NW, SC US complete.
# BURKES GARDEN, VA US complete.
# Cannot find SUGAR GROVE 4 NNE, WV US.
# WESTON, WV US complete.
# CANAAN VALLEY NUMBER 2, WV US complete.
# Cannot find CAMP PICKETT, VA US.
# MCROSS 3 E, WV US complete.
# OCEANA 2 SE, WV US complete.
# PIKE ISLAND LOCK AND DAM, WV US complete.
# MANNING, SC US complete.
# Cannot find HOLLAND 1 E, VA US.
# BARTOW 1 S, WV US complete.
# HARTSVILLE, SC US complete.
# WALHALLA, SC US complete.
# WINFIELD LOCKS, WV US complete.
# SOUTHSIDE 3 NNW, WV US complete.
# LAURENS, SC US complete.
# STERLING RCS, VA US complete.
# GREENWOOD, SC US complete.
# SULLIVANS ISLAND, SC US complete.
# Cannot find LYNCHBURG NUMBER 2, VA US.
# DISPUTANTA, VA US complete.
# BELINGTON, WV US complete.
# GLADY 1 N, WV US complete.
# PINEVILLE, WV US complete.
# SANDSTON, VA US complete.
# WEBSTER SPRINGS, WV US complete.
# WINNSBORO, SC US complete.
# BURTON, WV US complete.
# Cannot find SUFFOLK LAKE KILBY, VA US.
# CLARKS HILL 1 W, SC US complete.
# BENNETTSVILLE, SC US complete.
# Cannot find PARSONS 1 NE, WV US.
# PICKENS 2 N, WV US complete.
# EASTVILLE, VA US complete.
# CALHOUN FALLS, SC US complete.
# BAYARD, WV US complete.
# PHILIPPI, WV US complete.
# WEST UNION 2, WV US complete.
# VIENNA, VA US complete.
# Cannot find HOGSETT R.C. BYRD DAM, WV US.
# ANDREWS, SC US complete.
# TABLE ROCK, SC US complete.
# Cannot find NINETY NINE ISLANDS, SC US.
# MILLGAP, VA US complete.
# MCCOLL 3 NNW, SC US complete.
# WILLIAMSBURG 2 N, VA US complete.
# STAUNTON WATER TREATMENT PLANT, VA US complete.
# MARION, SC US complete.
# ASHLAND, VA US complete.
# Cannot find HAMPTON UNIVERSITY, VA US.
# GASSAWAY, WV US complete.
# HOT SPRINGS, VA US complete.
# TYE RIVER 1 SE, VA US complete.
# MYRTLE BEACH, SC US complete.
# WEST POINT 2 NW, VA US complete.
# WOODSTOCK 2 NE, VA US complete.
# SPENCER, WV US complete.
# PICKENS, SC US complete.
# STUART, VA US complete.
# BISHOPVILLE 1 ENE, SC US complete.
# COLUMBIA UNIVERSITY OF SC, SC US complete.
# ANDERSON CO AIRPORT, SC US complete.
# CAESARS HEAD, SC US complete.
# ANDERSON, SC US complete.
# BLAND, VA US complete.
# Cannot find WALLACETON LK DRUMND, VA US.
# Cannot find FROST 3 NE, WV US.
# MARLINTON, WV US complete.
# ROMNEY 1 SW, WV US complete.
# Cannot find MANASSAS, VA US.
# SALTVILLE 1 N, VA US complete.
# PETERSBURG, VA US complete.
# SPERRYVILLE, VA US complete.
# Cannot find GALAX RADIO WBRF, VA US.
# Cannot find GALAX WATER PLANT, VA US.
# WHEELING, WV US complete.
# SUMTER, SC US complete.
# NORTH MYRTLE BEACH GRAND STRAND AIRPORT, SC US complete.
# STAR TANNERY, VA US complete.
# LAKE CITY 2 SE, SC US complete.
# Cannot find BEAUFORT MCAS, SC US.
# CLEMSON OCONEE CO AIRPORT, SC US complete.
# Cannot find EDISTO ISLAND MIDDLETON PLANTATION, SC US.
# CHESTERFIELD 3 E, SC US complete.
# EDISTO BEACH STATE PARK, SC US complete.
# WALKERTON 2 NW, VA US complete.
# MADISON 3 NNW, WV US complete.
# Cannot find HOPEWELL, VA US.
# COVINGTON FILTER PLANT, VA US complete.
# Cannot find WAYNESBORO WATER TREATMENT, VA US.
# HARRISVILLE, WV US complete.
# WEST PELZER 2 W, SC US complete.
# LITTLE MOUNTAIN, SC US complete.
# HEMINGWAY 8 ESE, SC US complete.
# PELION 4 N, SC US complete.
# Cannot find BROOKNEAL, VA US.
# UNION 3 SSE, WV US complete.
# LINCOLN, VA US complete.
# CLARKSVILLE, VA US complete.
# CONWAY, SC US complete.
# CHESTER 1 SE, SC US complete.
# ELKINS RANDOLPH CO AIRPORT, WV US complete.
# Cannot find DANVILLE REGIONAL AIRPORT, VA US.
# BLACKVILLE 3 W, SC US complete.
# RADFORD 3 N, VA US complete.
# LOST RIVER, WV US complete.
# MARTINSVILLE FILTER PLANT, VA US complete.
# ANSTEAD HAWKS NEST STATE PARK, WV US complete.
# Cannot find RICHWOOD 1 SSE, WV US.
# Cannot find JOCASSEE 8 WNW, SC US.
# RICHLANDS, VA US complete.
# STAFFORDSVILLE 3 ENE, VA US complete.
# MORGANTOWN HART FIELD, WV US complete.
# MARTINSBURG EASTERN WEST VIRGINIA REGIONAL AIRPORT, WV US complete.
# LYNCHBURG INTERNATIONAL AIRPORT, VA US complete.
# ORANGEBURG 2, SC US complete.
# CHATHAM, VA US complete.
# BLACKSBURG NATIONAL WEATHER SERVICE OFFICE, VA US complete.
# ROCK CAVE 2 NE, WV US complete.
# HAMLIN, WV US complete.
# PENNINGTON GAP, VA US complete.
# FARMVILLE 2 N, VA US complete.
# CROZIER, VA US complete.
# WAKEFIELD 1 NW, VA US complete.
# STONY CREEK 2 N, VA US complete.
# LEWISBURG 3 N, WV US complete.
# SUMMERSVILLE LAKE, WV US complete.
# WINTHROP UNIVERSITY, SC US complete.
# WISE 1 SE, VA US complete.
# RIDGEVILLE, SC US complete.
# MCCORMICK, SC US complete.
# YEMASSEE 1 N, SC US complete.
# Cannot find LANGLEY AIR FORCE BASE, VA US.
# Cannot find PARKERSBURG AIRPORT, WV US.
# SANTUCK, SC US complete.
# CHESNEE 7 WSW, SC US complete.
# DUNLOW 1 SW, WV US complete.
# CLARKSBURG 1, WV US complete.
# Cannot find CHASE CITY, VA US.
# FRONT ROYAL, VA US complete.
# BECKLEY VA HOSPITAL, WV US complete.
# CLARKSBURG BENEDUM AIRPORT, WV US complete.
# DILLON, SC US complete.
# LOGAN, WV US complete.
# DARLINGTON, SC US complete.
# BREMO BLUFF, VA US complete.
# ALDERSON, WV US complete.
# MULLENS 3 E, WV US complete.
# TYGART DAM, WV US complete.
# ROANOKE 8 N, VA US complete.
# Cannot find GEORGETOWN CO AIRPORT, SC US.
# Cannot find FLORENCE 8 NE, SC US.
# Cannot find LURAY 5 E, VA US.
# WALTERBORO 1 SW, SC US complete.
# WARDENSVILLE R M FARM, WV US complete.
# HAW RIVER 1 E, NC US complete.
# BEECH MOUNTAIN, NC US complete.
# GREENVILLE, NC US complete.
# WILMINGTON 7 SE, NC US complete.
# FAIRFIELD, NC US complete.
# WASHINGTON WWTP 4 W, NC US complete.
# KINSTON AG RESEARCH, NC US complete.
# ROANOKE RAPIDS, NC US complete.
# CONCORD, NC US complete.
# ARCOLA, NC US complete.
# BREVARD, NC US complete.
# LEWISTON, NC US complete.
# OCRACOKE, NC US complete.
# WILMINGTON 7 N, NC US complete.
# GASTONIA, NC US complete.
# OXFORD AG, NC US complete.
# LEXINGTON, NC US complete.
# REIDSVILLE 2 NW, NC US complete.
# CHARLOTTE DOUGLAS AIRPORT, NC US complete.
# HIGHLANDS, NC US complete.
# ALBEMARLE, NC US complete.
# Cannot find TAPOCO, NC US.
# CHAPEL HILL WILLIAMS AIRPORT, NC US complete.
# MANTEO AIRPORT, NC US complete.
# ELIZABETH CITY, NC US complete.
# CELO 2 S, NC US complete.
# ENKA, NC US complete.
# LAURINBURG MAXTON AIRPORT, NC US complete.
# BURLINGTON ALAMANCE REGIONAL AIRPORT, NC US complete.
# HAYESVILLE 1 SW, NC US complete.
# WILSON 3 SW, NC US complete.
# JACKSON, NC US complete.
# MOORES CREEK NATIONAL BATTLEFIELD, NC US complete.
# SHELBY 2 NW, NC US complete.
# WHITEVILLE 7 NW, NC US complete.
# Cannot find AURORA 6 N, NC US.
# BURGAW 4 E, NC US complete.
# JACKSON SPRINGS 5 WNW, NC US complete.
# LAURINBURG, NC US complete.
# MURPHY 4 ESE, NC US complete.
# NEW HILL, NC US complete.
# EAST ARCADIA 2 NE, NC US complete.
# HIGH POINT, NC US complete.
# RAEFORD, NC US complete.
# REELSBORO, NC US complete.
# SURF CITY, NC US complete.
# LUMBERTON REGIONAL AIRPORT, NC US complete.
# WARSAW 5 E, NC US complete.
# BURLINGTON FIRE STATION NUMBER 5, NC US complete.
# MORGANTON, NC US complete.
# PISGAH FOREST 3 NE, NC US complete.
# SALISBURY 9 WNW, NC US complete.
# FAYETTEVILLE PWC, NC US complete.
# WATERVILLE 2, NC US complete.
# SALISBURY, NC US complete.
# CULLOWHEE, NC US complete.
# MOREHEAD CITY 2 WNW, NC US complete.
# NORTH WILKESBORO, NC US complete.
# ROBBINSVILLE 1 S, NC US complete.
# NEW RIVER MCAF, NC US complete.
# SPARTA, NC US complete.
# CAPE HATTERAS BILLY MITCHELL FIELD, NC US complete.
# JACKSONVILLE EOC, NC US complete.
# WILMINGTON INTERNATIONAL AIRPORT, NC US complete.
# ELIZABETHTOWN 3 SW, NC US complete.
# HAMLET, NC US complete.
# Cannot find CLINTON 2 NE, NC US.
# LINCOLNTON 4 W, NC US complete.
# FOREST CITY 8 W, NC US complete.
# RICHLANDS, NC US complete.
# SMITHFIELD, NC US complete.
# LUMBERTON, NC US complete.
# RALEIGH STATE UNIVERSITY, NC US complete.
# NEW BERN CRAVEN CO REGIONAL AIRPORT, NC US complete.
# LUMBER RIVER STATE PARK, NC US complete.
# RALEIGH 4 SW, NC US complete.
# HAVELOCK CHERRY POINT MCAS, NC US complete.
# ASHEVILLE, NC US complete.
# Cannot find BENT CREEK, NC US.
# DURHAM 11 W, NC US complete.
# DUNN 4 NW, NC US complete.
# CARY, NC US complete.
# ROXBORO 7 ESE, NC US complete.
# WALLACE 1 SE, NC US complete.
# WAYNESVILLE 1 E, NC US complete.
# ASHEBORO 2 W, NC US complete.
# WILLARD 4 SW, NC US complete.
# COWEETA EXPERIMENT STATION, NC US complete.
# WADESBORO, NC US complete.
# JEFFERSON, NC US complete.
# MARION, NC US complete.
# TRANSOU, NC US complete.
# FAYETTEVILLE REGIONAL AIRPORT GRANNIS FIELD, NC US complete.
# GREENSBORO AIRPORT, NC US complete.
# STATESVILLE 2 NNE, NC US complete.
# RALEIGH AIRPORT, NC US complete.
# Cannot find SWANSBORO BOGUE FIELD MCAF, NC US.
# COLUMBIA AG GUM NECK, NC US complete.
# DURHAM, NC US complete.
# LENOIR, NC US complete.
# HENDERSON 2 NNW, NC US complete.
# APEX, NC US complete.
# BAYBORO 3 E, NC US complete.
# CLAYTON WTP, NC US complete.
# EDENTON, NC US complete.
# SILER CITY, NC US complete.
# DANBURY, NC US complete.
# MOCKSVILLE 5 SE, NC US complete.
# YADKINVILLE 6 E, NC US complete.
# W. KERR SCOTT RESV., NC US complete.
# Cannot find CANDLER 1 W, NC US.
# FALLS LAKE, NC US complete.
# GRANDFATHER MOUNTAIN, NC US complete.
# PERRYTOWN, NC US complete.
# HOFMANN FOREST, NC US complete.
# TARBORO 1 S, NC US complete.
# Cannot find YANCEYVILLE 4 SE, NC US.
# Cannot find SPRUCE PINE 2 NE, NC US.
# HOT SPRINGS, NC US complete.
# GASTONIA MUNICIPAL AIRPORT, NC US complete.
# MONROE AIRPORT, NC US complete.
# BANNER ELK, NC US complete.
# Cannot find ASHEVILLE 8 SSW, NC US.
# HICKORY FAA AIRPORT, NC US complete.
# ASHEVILLE 13 S, NC US complete.
# Cannot find ASHEVILLE AIRPORT, NC US.
# BOONE, NC US complete.
# WILLIAMSTON 1 E, NC US complete.
# CHAPEL HILL 2 W, NC US complete.
# Cannot find LAKE TOXAWAY 2 SW, NC US.
# HENDERSONVILLE 1 NE, NC US complete.
# SHALLOTTE AG, NC US complete.
# LONGWOOD, NC US complete.
# MURFREESBORO, NC US complete.
# MARSHALL, NC US complete.
# SANFORD 8 NE, NC US complete.
# TRYON, NC US complete.
# LOUISBURG, NC US complete.
# Cannot find SOUTHPORT 5 N, NC US.
# WINSTON SALEM REYNOLDS AIRPORT, NC US complete.
# BEAUFORT MICHAEL J SMITH FIELD, NC US complete.
# ELIZABETH CITY COAST GUARD AIR STATION, NC US complete.
# CEDAR ISLAND, NC US complete.
# FLETCHER 3 W, NC US complete.
# Cannot find MOUNT MITCHELL, NC US.
# ATLANTIC BEACH WATER PLANT, NC US complete.
# TAYLORSVILLE, NC US complete.
# FRANKLIN, NC US complete.
# RURAL HALL, NC US complete.
# Cannot find PLYMOUTH 5 E, NC US.
# Cannot find CATALOOCHEE, NC US.
# ROCKY MOUNT WILSON AIRPORT, NC US complete.
# KINSTON, NC US complete.
# MONROE, NC US complete.
# FLAT SPRINGS 1 E, NC US complete.
# MOUNT AIRY 2 W, NC US complete.
# OCONALUFTEE, NC US complete.
# FAYETTEVILLE POPE AFB, NC US complete.
# GOLDSBORO SEYMOUR JOHNSON AFB, NC US complete.
# MORRISTOWN RADIO WCR, TN US complete.
# PRIDGEN, GA US complete.
# MORRISTOWN WEATHER FORECAST OFFICE, TN US complete.
# Cannot find BANKHEAD LOCK AND DAM, AL US.
# MOULTRIE 2 ESE, GA US complete.
# Cannot find DUBLIN, GA US.
# ROCKFORD, AL US complete.
# MOSCOW, TN US complete.
# CAMILLA 3 SE, GA US complete.
# CHATSWORTH 2, GA US complete.
# Cannot find LEWISBURG EXPERIMENTAL STATION, TN US.
# CHATTANOOGA LOVELL FIELD AIRPORT, TN US complete.
# CLAYTON 1 SSW, GA US complete.
# VALLEY HEAD, AL US complete.
# PHIL, KY US complete.
# STEARNS 2 S, KY US complete.
# Cannot find AUGUSTA BUSH FIELD AIRPORT, GA US.
# SAVANNAH INTERNATIONAL AIRPORT, GA US complete.
# PORTLAND SEWAGE PLANT, TN US complete.
# Cannot find SODDY DAISY MOWBRAY MOUNTAIN, TN US.
# EASTMAN 1 W, GA US complete.
# RUSSELLVILLE NUMBER 2, AL US complete.
# SPRINGFIELD EXPERIMENTAL STATION, TN US complete.
# MEMPHIS INTERNATIONAL AIRPORT, TN US complete.
# SELMA, AL US complete.
# KNOXVILLE MCGHEE TYSON AIRPORT, TN US complete.
# CRESTWOOD 4 NE, KY US complete.
# PADUCAH BARKLEY REGIONAL AIRPORT, KY US complete.
# NASHVILLE INTERNATIONAL AIRPORT, TN US complete.
# CLEVELAND FILTER PLANT, TN US complete.
# MUSCLE SHOALS REGIONAL AIRPORT, AL US complete.
# MONTGOMERY AIRPORT, AL US complete.
# PROVIDENCE, KY US complete.
# MOBILE REGIONAL AIRPORT, AL US complete.
# Cannot find PICKETT STATE PARK, TN US.
# MOUNTAIN CITY 2, TN US complete.
# Cannot find HUNTSVILLE INTERNATIONAL AIRPORT JONES FIELD, AL US.
# MONTEREY, TN US complete.
# QUITMAN 2 NW, GA US complete.
# CLARKESVILLE, GA US complete.
# LAWRENCEBURG FILTER PLANT, TN US complete.
# COLLIERVILLE, TN US complete.
# TROY, AL US complete.
# SAVANNAH 6 SW, TN US complete.
# THORSBY EXPERIMENTAL STATION, AL US complete.
# ELIZABETHTON, TN US complete.
# LONDON CORBIN AIRPORT, KY US complete.
# COLUMBIA 3 WNW, TN US complete.
# STANTON 2 W, KY US complete.
# MANCHESTER 4 W, KY US complete.
# WAYCROSS WARE CO AIRPORT, GA US complete.
# OAK RIDGE ATDD, TN US complete.
# CODEN, AL US complete.
# MONTEAGLE, TN US complete.
# PRINCETON 1 SE, KY US complete.
# CROSSVILLE MEMORIAL AIRPORT, TN US complete.
# ALBANY SW GEORGIA REGIONAL AIRPORT, GA US complete.
# Cannot find ASHBURN 3 ENE, GA US.
# PARSONS WATER PLANT, TN US complete.
# WARTRACE 6 E, TN US complete.
# WARNER PARK, TN US complete.
# CEDARTOWN, GA US complete.
# ANNISTON METROPOLITAN AIRPORT, AL US complete.
# Cannot find ALMA BACON CO AIRPORT, GA US.
# UNION SPRINGS 9 S, AL US complete.
# BRUNSWICK MALCOLM MCKINNON AIRPORT, GA US complete.
# BRISTOL TRI CITY AIRPORT, TN US complete.
# BIRMINGHAM AIRPORT, AL US complete.
# ATLANTA HARTSFIELD INTERNATIONAL AIRPORT, GA US complete.
# ATHENS BEN EPPS AIRPORT, GA US complete.
# MAYSVILLE SEWAGE PLANT, KY US complete.
# SILOAM 3 N, GA US complete.
# WASHINGTON, GA US complete.
# Cannot find TROY MUNICIPAL AIRPORT, AL US.
# SMYRNA 6 S, TN US complete.
# ALPHARETTA 4 SSW, GA US complete.
# WOODBURY 1 WNW, TN US complete.
# WAYNESBORO, TN US complete.
# DANIELSVILLE, GA US complete.
# CARTERSVILLE, GA US complete.
# LAFAYETTE 3 SW, GA US complete.
# JONESBORO, GA US complete.
# JACKSON, AL US complete.
# SMITHVILLE 2 SE, TN US complete.
# LA GRANGE, GA US complete.
# OPELIKA, AL US complete.
# SOMERSET 2 N, KY US complete.
# MURRAY, KY US complete.
# WARRENTON, GA US complete.
# PLAINS SW GA EXPERIMENTAL STATION, GA US complete.
# CUMMING 2 N, GA US complete.
# SPARTA WASTEWATER PLANT, TN US complete.
# VIENNA, GA US complete.
# TELLICO PLAINS, TN US complete.
# FAYETTEVILLE WATER PLANT, TN US complete.
# MOUNT PLEASANT 1 N, TN US complete.
# OAK MOUNTAIN STATE PARK, AL US complete.
# ONEONTA, AL US complete.
# PINSON, AL US complete.
# INEZ 2 E, KY US complete.
# Cannot find SAND MOUNTAIN SUBSTATION, AL US.
# Cannot find KENLAKE RESORT, KY US.
# NEWCOMB, TN US complete.
# LANCING 6 NW, TN US complete.
# MURFREESBORO 5 N, TN US complete.
# BUCKHORN LAKE, KY US complete.
# DONALSONVILLE, GA US complete.
# CLARKSVILLE OUTLAW AIRPORT, TN US complete.
# MILAN EXPERIMENTAL STATION, TN US complete.
# APPLING 2 NW, GA US complete.
# CARROLLTON, GA US complete.
# Cannot find WALNUT HILL 3 W, AL US.
# BAXLEY 5 NNW, GA US complete.
# PULASKI WATER PLANT, TN US complete.
# WOODBURY, KY US complete.
# BIG SANDY, TN US complete.
# DANVILLE, KY US complete.
# ROCHESTER FERRY, KY US complete.
# MOUNTAIN CITY 2 SW, GA US complete.
# WARNER ROBINS, GA US complete.
# Cannot find JACKSON JULIAN CARROLL AIRPORT, KY US.
# Cannot find ATLANTA FULTON CO AIRPORT, GA US.
# WINTERVILLE, GA US complete.
# LINDEN WATER PLANT, TN US complete.
# LANCASTER EDGAR EVINS, TN US complete.
# LENOIR CITY, TN US complete.
# CENTREVILLE 2.9 SW, AL US complete.
# SPRING CITY, TN US complete.
# GRAYSON 2 E, KY US complete.
# SCOTTSBORO, AL US complete.
# Cannot find WINFIELD 2 SW, AL US.
# FRANKFORT LOCK 4, KY US complete.
# VERNON, AL US complete.
# HIGHLAND HOME 2 S, AL US complete.
# Cannot find TALLADEGA 10 NNE, AL US.
# FRANKLIN SEWAGE PLANT, TN US complete.
# CHICKAMAUGA PARK LARC, GA US complete.
# THOMASTON 4 SE, GA US complete.
# THOMASVILLE 7 NE, GA US complete.
# NASHVILLE 4 N, GA US complete.
# Cannot find PEACHTREE CITY FALCON FIELD, GA US.
# BAY MINETTE, AL US complete.
# Cannot find NEAPOLIS EXPERIMENTAL STATION, TN US.
# ROGERSVILLE 1 NE, TN US complete.
# GADSDEN 19 N, AL US complete.
# FAYETTE, AL US complete.
# SELMA 13 WNW, AL US complete.
# Cannot find FALL CREEK FALLS SP, TN US.
# CROSSVILLE 7 NW, TN US complete.
# Cannot find BRUNSWICK 23 S, GA US.
# VALLEY HEAD 1 SSW, AL US complete.
# MOUSETAIL LANDING STATE PARK, TN US complete.
# BARDWELL 2 E, KY US complete.
# Cannot find MAMMOTH CAVE, KY US.
# EVERGREEN MIDDLETON FIELD, AL US complete.
# HAWKINSVILLE, GA US complete.
# EVERGREEN, AL US complete.
# WOODBINE, GA US complete.
# HODGENVILLE LINCOLN, KY US complete.
# LIVINGSTON RADIO WLIV, TN US complete.
# TALBOTTON, GA US complete.
# LEXINGTON 10 NW, TN US complete.
# COURTLAND 2 WSW, AL US complete.
# FAIRHOPE 3 NE, AL US complete.
# GUNTERSVILLE 2 SW, AL US complete.
# CULLMAN 3 ENE, AL US complete.
# LEXINGTON, TN US complete.
# EUFAULA WEEDON FIELD AIRPORT, AL US complete.
# FLORALA MUNICIPAL AIRPORT, AL US complete.
# RUSSELLVILLE, KY US complete.
# GAINESVILLE LEE GILMER MEMORIAL AIRPORT, GA US complete.
# MOUNT MORIAH BIRDSONG, TN US complete.
# HENDERSON 4 W, TN US complete.
# THOMASVILLE, AL US complete.
# BOONEVILLE 12 SW, KY US complete.
# LOBELVILLE, TN US complete.
# LEBANON 7 N, TN US complete.
# Cannot find MOUNT LECONTE, TN US.
# TAZEWELL, TN US complete.
# ELBERTON 2 N, GA US complete.
# FRANKFORT CAPITAL CITY AIRPORT, KY US complete.
# Cannot find ANDALUSIA OPP AIRPORT, AL US.
# EUFAULA WILDLIFE REF, AL US complete.
# Cannot find NEWNAN 7 WNW, GA US.
# MANCHESTER NUMBER 2, TN US complete.
# BERNHEIM FOREST, KY US complete.
# Cannot find RUSSELLVILLE 4 SSE, AL US.
# WHITE HOUSE, TN US complete.
# Cannot find NAHUNTA 6 NE, GA US.
# SCOTTSBORO 2 NE, AL US complete.
# GREENSBORO 2 WNW, AL US complete.
# MUSCLE SHOALS 2 N, AL US complete.
# CLANTON 2 NE, AL US complete.
# GAINESVILLE 2 NE, AL US complete.
# LEBANON, TN US complete.
# DECATUR PRYOR FIELD, AL US complete.
# HIGHLAND HOME, AL US complete.
# AUBURN NUMBER 2, AL US complete.
# BLAKELY, GA US complete.
# Cannot find DECATUR 7 NE, TN US.
# JACKSON 4 NE, TN US complete.
# Cannot find CORNERS, KY US.
# ROCKWOOD 2, TN US complete.
# ONEIDA, KY US complete.
# WARSAW MARKLAND DAM, KY US complete.
# Cannot find LEESBURG 2, GA US.
# Cannot find NEWTON 8 W, GA US.
# TUSCALOOSA ACFD, AL US complete.
# Cannot find NEWTON 11 SW, GA US.
# BELLE MINA, AL US complete.
# RIPLEY, TN US complete.
# Cannot find BOONEVILLE 1 SE, KY US.
# CHILDERSBURG WATER PLANT, AL US complete.
# ALLARDT, TN US complete.
# JACKSON EXPERIMENTAL STATION, TN US complete.
# BEREA COLLEGE, KY US complete.
# TALLADEGA, AL US complete.
# NORRIS, TN US complete.
# TENNESSEE RIDGE, TN US complete.
# LYNCHBURG, TN US complete.
# PARIS 2 SE, TN US complete.
# MADISONVILLE, KY US complete.
# MCDANIELS, KY US complete.
# JAMESTOWN, TN US complete.
# BESSEMER 3 WSW, AL US complete.
# ATMORE, AL US complete.
# THOMPSON STATION, TN US complete.
# WINCHESTER 5 SE, TN US complete.
# VERSAILLES 3 NNW, KY US complete.
# NEWPORT 1 NW, TN US complete.
# MULBERRY GROVE, GA US complete.
# MARTIN UNIVERSITY OF TN EXPERIMENT STATION, TN US complete.
# OWENS CROSS ROADS 3 S, AL US complete.
# SAINT BERNARD, AL US complete.
# BRADFORDSVILLE, KY US complete.
# SCOTTSVILLE, KY US complete.
# SPOTTSVILLE, KY US complete.
# FAIRHOPE 2 NE, AL US complete.
# CLAYTON, AL US complete.
# BLAIRSVILLE EXPERIMENTAL STATION, GA US complete.
# LEXINGTON, GA US complete.
# LOOKOUT MTN POINT PARK, TN US complete.
# SUMMERVILLE, GA US complete.
# BOWLING GREEN 21 NNE, KY US complete.
# HOHENWALD, TN US complete.
# BALL GROUND, GA US complete.
# BRANDENBURG, KY US complete.
# GAINESBORO, TN US complete.
# Cannot find ROCK MILLS, AL US.
# WATKINSVILLE 5 SSE, GA US complete.
# PAINTSVILLE 1 E, KY US complete.
# WEST PADUCAH 2 W, KY US complete.
# WARNOCK2, KY US complete.
# WEST LIBERTY 11 NW, KY US complete.
# WEST LIBERTY 3 NW, KY US complete.
# MARROWBONE, KY US complete.
# OLIVE HILL 5 NE, KY US complete.
# DEMOPOLIS LOCK AND DAM, AL US complete.
# GUNTERSVILLE NUMBER 2, AL US complete.
# TIFTON, GA US complete.
# ADDISON, AL US complete.
# LOUISVILLE 1 E, GA US complete.
# GUNTERSVILLE, AL US complete.
# DOVER 1 W, TN US complete.
# GREENEVILLE EXPERIMENTAL STATION, TN US complete.
# COLUMBUS NUMBER 2, GA US complete.
# MUSCLE SHOALS 3 NE, AL US complete.
# HOPKINSVILLE, KY US complete.
# COVINGTON 3 SW, TN US complete.
# ALAMO 1 N, TN US complete.
# COLQUITT 2 W, GA US complete.
# MOULTON 2, AL US complete.
# BEATTYVILLE 4 N, KY US complete.
# ONEIDA, TN US complete.
# ROME, GA US complete.
# ALICEVILLE, AL US complete.
# MCDONOUGH, GA US complete.
# ATHENS, TN US complete.
# ASHLAND, KY US complete.
# KINGSTON SPRINGS, TN US complete.
# MEMPHIS ZOO, TN US complete.
# CALHOUN LOCK 2, KY US complete.
# CORNELIA, GA US complete.
# BEAVER DAM, KY US complete.
# HENDERSON 8 SSW, KY US complete.
# FARMERS 2 S, KY US complete.
# MC MINNVILLE, TN US complete.
# GLADEVILLE, TN US complete.
# HAZLEHURST, GA US complete.
# DICKSON, TN US complete.
# LEITCHFIELD 2 N, KY US complete.
# Cannot find FOLKSTON 9 SW, GA US.
# Cannot find COOKEVILLE, TN US.
# BRENTWOOD, TN US complete.
# DAYTON 2 SE, TN US complete.
# LYONS, GA US complete.
# Cannot find JESUP 8 S, GA US.
# HELENA, AL US complete.
# MABLETON 1 N, GA US complete.
# Cannot find CENTRE, AL US.
# HUNTINGDON WATER PLA, TN US complete.
# ALEXANDER CITY, AL US complete.
# BROWNSVILLE, TN US complete.
# CORDELE, GA US complete.
# SAUTEE 3 W, GA US complete.
# LOUISVILLE WEATHER FORECAST OFFICE, KY US complete.
# GERMANTOWN 4 SE, TN US complete.
# HEIDELBERG 2 N, KY US complete.
# ROCK ISLAND STATE PARK, TN US complete.
# Cannot find TOWNSEND 5 S, TN US.
# DECATUR 5 SE, AL US complete.
# TOCCOA, GA US complete.
# HANCEVILLE, AL US complete.
# LAFAYETTE 2 W, AL US complete.
# HEFLIN, AL US complete.
# TROY 2 W, AL US complete.
# BREWTON 3 NNE, AL US complete.
# SANDERSVILLE, GA US complete.
# ANDERSON, AL US complete.
# Cannot find SELMA 6 SSE, AL US.
# GOODLETTSVILLE 7 WNW, TN US complete.
# Cannot find CRESSY, KY US.
# Cannot find ATHENS, AL US.
# ATLANTA DEKALB PEACHTREE AIRPORT, GA US complete.
# CRAB ORCHARD 6 N, KY US complete.
# ALABASTER SHELBY CO AIRPORT, AL US complete.
# OAK RIDGE ASOS, TN US complete.
# Cannot find HAMILTON 3 S, AL US.
# VALDOSTA, GA US complete.
# ENTERPRISE 2 W, AL US complete.
# HARTWELL, GA US complete.
# HEADLAND, AL US complete.
# Cannot find HARTWELL DAM, GA US.
# ANDALUSIA 3 W, AL US complete.
# ELIZABETHTOWN, KY US complete.
# ROCKY FORD 4 SE, GA US complete.
# Cannot find THOMASVILLE 2 S, AL US.
# BAXTER, KY US complete.
# CARTERSVILLE AIRPORT, GA US complete.
# GREENVILLE, AL US complete.
# ASHLAND, AL US complete.
# CARTHAGE, TN US complete.
# KINGSTON, TN US complete.
# GREENSBORO, AL US complete.
# Cannot find GATLINBURG 2 SW, TN US.
# CHARLEY 2 SW, KY US complete.
# CLANTON, AL US complete.
# MEMPHIS WEATHER FORECAST OFFICE, TN US complete.
# BARREN RIVER LAKE, KY US complete.
# CROSSVILLE EXPERIMENTAL STATION, TN US complete.
# OLD HICKORY WEATHER FORECAST OFFICE, TN US complete.
# CYNTHIANA, KY US complete.
# LAFAYETTE, TN US complete.
# CAMP HILL 2 NW, AL US complete.
# CHATOM, AL US complete.
# HELEN, GA US complete.
# IRWINTON 4 WNW, GA US complete.
# U OF GA PLANT SCIENCE FARM, GA US complete.
# HALEYVILLE, AL US complete.
# CAMDEN, TN US complete.
# KINGSPORT, TN US complete.
# CENTERVILLE 4 NE, TN US complete.
# Cannot find AMES PLANTATION, TN US.
# JEFFERSON CITY, TN US complete.
# COMMERCE 4 NNW, GA US complete.
# COVINGTON, GA US complete.
# SEVIERVILLE, TN US complete.
# KITE, GA US complete.
# MARION JUNCTION 2 NE, AL US complete.
# JAMESTOWN, KY US complete.
# CULLMAN NAHS, AL US complete.
# AMERICUS, GA US complete.
# CAIRO, GA US complete.
# FAIRVIEW BOWIE NAT CTR, TN US complete.
# BRUNSWICK, GA US complete.
# ABBEVILLE, GA US complete.
# ROUGH RIVER LAKE, KY US complete.
# LEXINGTON BLUEGRASS AIRPORT, KY US complete.
# LOUISVILLE INTERNATIONAL AIRPORT, KY US complete.
# GIMLET 9 N, KY US complete.
# WAYCROSS 4 NE, GA US complete.
# Cannot find WAVERLY AIRPORT, TN US.
# SELMER, TN US complete.
# FORT STEWART, GA US complete.
# GEORGETOWN 4 E, GA US complete.
# FORT PAYNE, AL US complete.
# CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIRPORT, KY US complete.
# CHARLOTTE, TN US complete.
# COALMONT, TN US complete.
# ALBANY 3 SE, GA US complete.
# WETUMPKA, AL US complete.
# LOUISVILLE BOWMAN FIELD, KY US complete.
# WAYNESBORO, GA US complete.
# CELINA, TN US complete.
# Cannot find BRIDGEPORT 5 NW, AL US.
# GADSDEN, AL US complete.
# ALTO 4 SE, GA US complete.
# METTER, GA US complete.
# GAINESVILLE, GA US complete.
# CLARKSVILLE NUMBER 2, TN US complete.
# KNOXVILLE EXPERIMENTAL STATION, TN US complete.
# BYRDSTOWN, TN US complete.
# Cannot find GAINESVILLE LOCK, AL US.
# SYLACAUGA 4 NE, AL US complete.
# COLUMBUS METROPOLITAN AIRPORT, GA US complete.
# VALDOSTA REGIONAL AIRPORT, GA US complete.
# SAMBURG W. L. REFUGE, TN US complete.
# TULLAHOMA, TN US complete.
# SEWANEE, TN US complete.
# CLARKSVILLE SEWAGE PLANT, TN US complete.
# GLENNVILLE, GA US complete.
# MOUNT VERNON, KY US complete.
# Cannot find CHEATHAM LOCK AND DAM, TN US.
# MEMPHIS NAS, TN US complete.
# DOUGLAS, GA US complete.
# MONTICELLO 3 NE, KY US complete.
# GILBERTSVILLE KY DAM, KY US complete.
# WEST POINT, GA US complete.
# DOTHAN REGIONAL AIRPORT, AL US complete.
# MOBILE DOWNTOWN AIRPORT, AL US complete.
# AUGUSTA DANIEL FIELD AIRPORT, GA US complete.
# JASPER, AL US complete.
# MILLEDGEVILLE, GA US complete.
# Cannot find FARGO 17 NE, GA US.
# DAUPHIN ISLAND NUMBER 2, AL US complete.
# BREWTON 3 SSE, AL US complete.
# MONTGOMERY 6 SW, AL US complete.
# BROOKLET 1 W, GA US complete.
# DAHLONEGA 4 WSW, GA US complete.
# Cannot find HOMERVILLE 5 N, GA US.
# BREWTON 3 ENE, AL US complete.
# UNION CITY, TN US complete.
# GREENSBURG, KY US complete.
# Cannot find MILSTEAD, AL US.
# Cannot find WHITWELL SEQUATCHIE VLY, TN US.
# MONTGOMERY BELL SP, TN US complete.
# Cannot find MIDVILLE EXPERIMENTAL STATION, GA US.
# SHELBYVILLE WATER, TN US complete.
# CLEVELAND, GA US complete.
# CHRISTIANA 5 W, TN US complete.
# FORT GAINES 2, GA US complete.
# MONTICELLO, GA US complete.
# GENEVA NUMBER 2, AL US complete.
# PATTERSON, GA US complete.
# ERWIN 1 W, TN US complete.
# DALLAS 7 NE, GA US complete.
# Cannot find SAPELO ISLAND, GA US.
# WEST POINT, AL US complete.
# BOLIVAR WATER WORKS, TN US complete.
# Cannot find CRISP CO POWER DAM, GA US.
# Cannot find ALLATOONA DAM 2, GA US.
# PIKEVILLE, TN US complete.
# WATERTOWN PUBLIC SAFETY COMPLEX, TN US complete.
# Cannot find JACKSON MCKELLAR SIPES REGIONAL AIRPORT, TN US.
# MACON MIDDLE GA REGIONAL AIRPORT, GA US complete.
# DRESDEN, TN US complete.
# JASPER 1 NNW, GA US complete.
# TUSCALOOSA MUNICIPAL AIRPORT, AL US complete.
# Cannot find BOWLING GREEN WARREN CO AIRPORT, KY US.
# CUTHBERT, GA US complete.
# NOLIN RIVER LAKE, KY US complete.
# Cannot find ROBERTSDALE, AL US.
# BARBOURVILLE, KY US complete.
# BETHPAGE 1 S, TN US complete.
# DYERSBURG MUNICIPAL AIRPORT, TN US complete.
# EDDYVILLE 5 S, KY US complete.
# Cannot find HARTSVILLE, TN US.
# ROME R B RUSSELL AIRPORT, GA US complete.
# LIVINGSTON, AL US complete.
# Cannot find DIX DAM, KY US.
# BARDSTOWN 5 E, KY US complete.
# ETOILE, KY US complete.
# EAGLEVILLE 1 SW, TN US complete.
# Reverse geocoding complete.

# %%
# Extract out stations that are missing county and zip code
missing_geocode = stations.loc[stations['COUNTY'].isnull()]
missing_geocode
# Out:
#          STATION                                            NAME  LATITUDE  \
# 47   USC00440720                              BIG MEADOWS, VA US  38.52160
# 52   USC00461900                COOPERS ROCK STATE FOREST, WV US  39.67722
# 55   USC00464971                                KUMBRABOW, WV US  38.63110
# 56   USC00443310                            GATHRIGHT DAM, VA US  37.94580
# 62   USC00468662                              SUTTON LAKE, WV US  38.66110
# ..           ...                                             ...       ...
# 912  USW00003811  JACKSON MCKELLAR SIPES REGIONAL AIRPORT, TN US  35.59300
# 917  USW00093808          BOWLING GREEN WARREN CO AIRPORT, KY US  36.96470
# 920  USC00016988                              ROBERTSDALE, AL US  30.56540
# 925  USC00403938                               HARTSVILLE, TN US  36.37556
# 928  USC00152214                                  DIX DAM, KY US  37.78580
#
#      LONGITUDE STATE               COORD COUNTY  ZIP
# 47   -78.43550    VA    38.5216,-78.4355    NaN  NaN
# 52   -79.77194    WV  39.67722,-79.77194    NaN  NaN
# 55   -80.08560    WV    38.6311,-80.0856    NaN  NaN
# 56   -79.95420    VA    37.9458,-79.9542    NaN  NaN
# 62   -80.69700    WV     38.6611,-80.697    NaN  NaN
# ..         ...   ...                 ...    ...  ...
# 912  -88.91670    TN     35.593,-88.9167    NaN  NaN
# 917  -86.42380    KY    36.9647,-86.4238    NaN  NaN
# 920  -87.70180    AL    30.5654,-87.7018    NaN  NaN
# 925  -86.18083    TN  36.37556,-86.18083    NaN  NaN
# 928  -84.70770    KY    37.7858,-84.7077    NaN  NaN
#
# [111 rows x 8 columns]
